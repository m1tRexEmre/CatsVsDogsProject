# %%
import os

base_path = "/kaggle/input"
for root, dirs, files in os.walk(base_path):
    print(root, len(files))
# Out:
# /kaggle/input 0
# /kaggle/input/microsoft-catsvsdogs-dataset 2
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages 0
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog 12501
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat 12501

# %% [markdown]
# ## Veri Klasör Yapısını Görüntüleme
#
# Bu kod, `/kaggle/input` klasörü altındaki tüm dizinleri ve her dizindeki dosya sayısını listeler.
# Amaç, veri setinin klasör yapısını ve içindeki dosya sayısını hızlıca kontrol etmektir.

# %%
import os

base_path = "/kaggle/input"
for root, dirs, files in os.walk(base_path):
    print(root, "->", len(files), "dosya")
# Out:
# /kaggle/input -> 0 dosya
# /kaggle/input/microsoft-catsvsdogs-dataset -> 2 dosya
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages -> 0 dosya
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog -> 12501 dosya
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat -> 12501 dosya

# %% [markdown]
# ## Veri Klasör Yapısını Kontrol Etme
#
# Bu kod, `/kaggle/input` klasörü altındaki tüm dizinleri ve her dizinde kaç dosya olduğunu listeler.
# Amaç, veri setinin doğru şekilde yüklendiğini ve dosya sayısını kontrol etmektir.
#
# ```python

# %%
import os, cv2

cat_dir = "/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat"
dog_dir = "/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog"

def clean_images(folder):
    bad_files = []
    for file in os.listdir(folder):
        path = os.path.join(folder, file)
        try:
            img = cv2.imread(path)
            if img is None:
                bad_files.append(path)
        except:
            bad_files.append(path)
    return bad_files

bad_cats = clean_images(cat_dir)
bad_dogs = clean_images(dog_dir)

print("Bozuk kedi resimleri:", bad_cats)
print("Bozuk köpek resimleri:", bad_dogs)
# Out:
# Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# Warning: unknown JFIF revision number 0.00
# Corrupt JPEG data: 254 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1403 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 2230 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# Bozuk kedi resimleri: ['/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/4833.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/850.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/8470.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/11210.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/660.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/140.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/10820.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/10501.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/9171.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/9778.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/2663.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/11935.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/10125.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/11874.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/936.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/Thumbs.db', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/5553.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/7978.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/3491.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/3300.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/666.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/7968.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/11565.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/10404.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/9565.jpg']
# Bozuk köpek resimleri: ['/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/6059.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11849.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/3288.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/6238.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/2688.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7112.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/8730.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11702.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7133.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11853.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7969.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7459.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/10747.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/6718.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/2877.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/3136.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11675.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/4367.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/Thumbs.db', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/5604.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/9188.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/3588.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11410.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/1308.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/10158.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/2384.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/1866.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7369.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/10797.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/10401.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/5736.jpg']

# %% [markdown]
# ### Bu hücre, veri setindeki bozuk veya açılamayan resimleri tespit eder. Sonuç olarak, bozuk resimler ekrana yazdırılır ve sonraki adımlarda bu dosyalar silinebilir.

# %%
import os
import cv2
import shutil

# Orijinal veri seti dizinleri
cat_dir = "/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat"
dog_dir = "/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog"

# Temiz veri seti için yeni klasör
clean_base = "/kaggle/working/cats_and_dogs_clean"
os.makedirs(clean_base, exist_ok=True)

def copy_good_images(src_folder, dest_folder):
    os.makedirs(dest_folder, exist_ok=True)
    for file in os.listdir(src_folder):
        src_path = os.path.join(src_folder, file)
        try:
            img = cv2.imread(src_path)
            if img is not None:
                shutil.copy(src_path, dest_folder)
        except:
            continue

# Kedi ve köpek resimlerini temiz klasöre kopyala
copy_good_images(cat_dir, os.path.join(clean_base, "Cat"))
copy_good_images(dog_dir, os.path.join(clean_base, "Dog"))

print("Temiz veri klasörü hazır:", clean_base)
# Out:
# Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# Warning: unknown JFIF revision number 0.00
# Corrupt JPEG data: 254 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1403 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 2230 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# Temiz veri klasörü hazır: /kaggle/working/cats_and_dogs_clean

# %% [markdown]
# ### Bu hücre, Kaggle input dizini salt okunur olduğu için bozuk dosyaları silmek yerine, sağlam görselleri yeni bir klasöre kopyalar. Sonuç olarak, bozuk dosyalar filtrelenmiş ve model eğitimi için hazır bir veri seti oluşturulur.

# %%
import os
import shutil
import random

random.seed(42)

split_base = "/kaggle/working/cats_and_dogs_split"
for folder in ["train", "val", "test"]:
    for label in ["Cat", "Dog"]:
        os.makedirs(os.path.join(split_base, folder, label), exist_ok=True)

for label in ["Cat", "Dog"]:
    files = os.listdir(os.path.join(clean_base, label))
    random.shuffle(files)
    n = len(files)
    train_end = int(0.7 * n)
    val_end = int(0.85 * n)

    for i, file in enumerate(files):
        src = os.path.join(clean_base, label, file)
        if i < train_end:
            dst = os.path.join(split_base, "train", label, file)
        elif i < val_end:
            dst = os.path.join(split_base, "val", label, file)
        else:
            dst = os.path.join(split_base, "test", label, file)
        shutil.copy(src, dst)

print("Train/Validation/Test ayrımı tamamlandı!")
# Out:
# Train/Validation/Test ayrımı tamamlandı!

# %% [markdown]
# ## Bu hücre, temizlenmiş kedi ve köpek resimlerini eğitim, doğrulama ve test setlerine böler. %70 eğitim (train)
#
# %15 doğrulama (val)
# %15 test (test)
# shutil.copy ile sağlam resimler ilgili alt klasörlere kopyalanır
# Sonuç olarak, model eğitimi için hazır bir veri seti yapısı elde edilir.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # 0=all, 1=info, 2=warning, 3=error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2025-09-25 23:10:19.906751: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758841820.111212      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758841820.172848      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ### Bu hücre, derin öğrenme modeli oluşturmak için gerekli kütüphaneleri yükler. TensorFlow uyarı mesajlarını gizler (sadece kritik hatalar görünür)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Train verisi için augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Validation ve test verisi için sadece rescale
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Dizinleri tanımla
train_dir = "/kaggle/working/cats_and_dogs_split/train"
val_dir = "/kaggle/working/cats_and_dogs_split/val"
test_dir = "/kaggle/working/cats_and_dogs_split/test"

# Data generatorları oluştur
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary'
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary'
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 17462 images belonging to 2 classes.
# Found 3741 images belonging to 2 classes.
# Found 3743 images belonging to 2 classes.

# %% [markdown]
# ## Bu hücre, modelin eğitimi için veri üreteçlerini (generators) hazırlar. Bu yapı ile model, veriyi memory’ye yüklemeden, batch batch eğitilebilir.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # binary classification için
])

model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1758841878.441878      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1758841878.442689      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 36992)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    18,940,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,034,177 (72.61 MB)
#  Trainable params: 19,034,177 (72.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Bu çıktı, modelin doğru şekilde oluşturulduğunu ve eğitime hazır olduğunu gösterir. Model Mimarisi (Sequential), Model Derleme ve Model Özeti kısımlarını içerir.

# %%
# Modeli eğit
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=val_generator,
    validation_steps=val_generator.samples // val_generator.batch_size,
    epochs=10  # Dilersen 15-20 yapabilirsin
)

# Accuracy grafiği
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss grafiği
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758841902.962635     141 service.cc:148] XLA service 0x785fc8004d80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1758841902.963494     141 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1758841902.963516     141 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1758841903.318977     141 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/545 ━━━━━━━━━━━━━━━━━━━━ 1:02:29 7s/step - accuracy: 0.4375 - loss: 0.6945
# I0000 00:00:1758841907.204225     141 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 131s 227ms/step - accuracy: 0.5246 - loss: 0.7501 - val_accuracy: 0.6371 - val_loss: 0.6352
# Epoch 2/10
#   1/545 ━━━━━━━━━━━━━━━━━━━━ 18s 34ms/step - accuracy: 0.5938 - loss: 0.6976
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.5938 - loss: 0.6976 - val_accuracy: 0.6404 - val_loss: 0.6357
# Epoch 3/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 120s 221ms/step - accuracy: 0.6373 - loss: 0.6371 - val_accuracy: 0.7031 - val_loss: 0.5693
# Epoch 4/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.7812 - loss: 0.5739 - val_accuracy: 0.7131 - val_loss: 0.5619
# Epoch 5/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 120s 220ms/step - accuracy: 0.6893 - loss: 0.5818 - val_accuracy: 0.7422 - val_loss: 0.5175
# Epoch 6/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.7500 - loss: 0.5122 - val_accuracy: 0.7346 - val_loss: 0.5218
# Epoch 7/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 120s 220ms/step - accuracy: 0.7280 - loss: 0.5435 - val_accuracy: 0.7495 - val_loss: 0.5064
# Epoch 8/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7500 - loss: 0.5434 - val_accuracy: 0.7387 - val_loss: 0.5208
# Epoch 9/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 120s 220ms/step - accuracy: 0.7400 - loss: 0.5238 - val_accuracy: 0.7651 - val_loss: 0.5108
# Epoch 10/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.7500 - loss: 0.5628 - val_accuracy: 0.7745 - val_loss: 0.4907

# %% [markdown]
# ## Model Eğitimi ve Eğitim Grafikleri¶
# Model Fit:
#
# train_generator ve val_generator kullanılarak model 10 epoch boyunca eğitilir
# steps_per_epoch ve validation_steps batch sayısına göre hesaplanır
# Accuracy Grafiği:
#
# history.history['accuracy'] → eğitim doğruluğu
# history.history['val_accuracy'] → doğrulama doğruluğu
# Epoch ilerledikçe modelin performansı gözlemlenir
# Loss Grafiği:
#
# history.history['loss'] → eğitim kaybı
# history.history['val_loss'] → doğrulama kaybı
# Modelin öğrenme durumu ve overfitting kontrolü yapılabilir
# Bu görselleştirmeler ile modelin eğitim süreci detaylı olarak izlenebilir.

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Test seti üzerinde tahmin yap
y_pred = model.predict(test_generator)
y_pred_classes = np.where(y_pred > 0.5, 1, 0)

# Gerçek etiketler
y_true = test_generator.classes

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Cat','Dog'], yticklabels=['Cat','Dog'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(y_true, y_pred_classes, target_names=['Cat','Dog']))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 114/117 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step
#               precision    recall  f1-score   support
#
#          Cat       0.85      0.64      0.73      1872
#          Dog       0.71      0.89      0.79      1871
#
#     accuracy                           0.76      3743
#    macro avg       0.78      0.76      0.76      3743
# weighted avg       0.78      0.76      0.76      3743

# %% [markdown]
# ## Test Seti ile Model Değerlendirme
# Tahmin Yapma:
#
# model.predict(test_generator) ile test verisi üzerinde tahminler alınır
# y_pred_classes ile tahminler 0 veya 1 olarak binary sınıflara çevrilir
# Confusion Matrix (Karmaşıklık Matrisi):
#
# Modelin doğru ve yanlış tahminleri görselleştirilir
# sns.heatmap ile kolay okunabilir bir matris çizilir
# Classification Report:
#
# precision, recall, f1-score ve support değerleri hesaplanır
# Hangi sınıfta modelin performansının daha iyi olduğunu gösterir
# Bu adım modelin gerçek test verisi üzerindeki başarısını detaylı olarak analiz eder.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model

def get_img_array(img_path, size):
    # Görüntüyü oku ve boyutlandır
    img = tf.keras.utils.load_img(img_path, target_size=size)
    array = tf.keras.utils.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    array /= 255.0
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]
    
    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0,1,2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def display_gradcam(img_path, heatmap, alpha=0.4):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    heatmap_color = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    superimposed_img = cv2.addWeighted(img, 1-alpha, heatmap_color, alpha, 0)
    
    plt.figure(figsize=(6,6))
    plt.imshow(superimposed_img)
    plt.axis('off')
    plt.show()

# %% [markdown]
# # Grad-CAM Görselleştirmesi için Fonksiyonlar
# Görseli Hazırlama (get_img_array)
#
# Görseli okur, target_size ile boyutlandırır ve 0-1 arasında normalize eder
# Grad-CAM Isı Haritası Üretme (make_gradcam_heatmap)
#
# Son konvolüsyon katmanı üzerinden sınıf aktivasyonlarını hesaplar
# Grad-CAM tekniği ile hangi bölgelerin sınıf tahminine etkili olduğunu görselleştirmek için ısı haritası üretir
# Grad-CAM Görselleştirme (display_gradcam)
#
# Orijinal görsel ile ısı haritasını üst üste bindirir
# alpha parametresi ile ısı haritasının şeffaflığı ayarlanabilir
# Bu fonksiyonlar sayesinde modelin hangi bölgelere dikkat ederek tahmin yaptığını görselleştirebilirsin.

# %%
import os

# Test Cat ve Dog klasöründeki dosyaları listele
cat_test_files = os.listdir("/kaggle/working/cats_and_dogs_split/test/Cat")
dog_test_files = os.listdir("/kaggle/working/cats_and_dogs_split/test/Dog")

# Örnek olarak ilk Cat görselini seç
img_path = "/kaggle/working/cats_and_dogs_split/test/Cat/" + cat_test_files[0]

print("Grad-CAM uygulanacak görsel:", img_path)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Grad-CAM uygulanacak görsel: /kaggle/working/cats_and_dogs_split/test/Cat/407.jpg

# %% [markdown]
# ## Grad-CAM için Örnek Görsel Seçimi
# Test Setindeki Görsellerin Listelenmesi:
#
# Cat ve Dog klasörlerindeki dosyalar os.listdir ile alınır
# Örnek Görsel Seçimi:
#
# İlk Cat görseli örnek olarak seçilir
# img_path değişkeni ile Grad-CAM uygulanacak görselin yolu belirlenir
# Bilgilendirme:
#
# print ile seçilen görselin yolu gösterilir

# %%
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model

# Görseli oku ve boyutlandır
def get_img_array(img_path, size=(150,150)):
    img = tf.keras.utils.load_img(img_path, target_size=size)
    array = tf.keras.utils.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    array /= 255.0
    return array

# Grad-CAM heatmap oluştur
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]

    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0,1,2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# Grad-CAM görselleştir
def display_gradcam(img_path, heatmap, alpha=0.4):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ## Grad-CAM ile Görsel Analizi
# Modelin tahminlerde hangi bölgelere dikkat ettiğini görselleştirmek için Grad-CAM yöntemi kullanılmıştır.

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Görseli array’e çevir
img_array = get_img_array(img_path, size=(150,150))


# Modelden tahmin al (bu aynı zamanda modelin çağrılmasını sağlar)
preds = model.predict(img_array)
print("Tahmin:", preds)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 741ms/step
# Tahmin: [[0.8025174]]

# %% [markdown]
# ## Tek Görsel Tahmini
# Seçilen test görseli modelden geçirilmiş ve tahmin sonucu ekrana yazdırılmıştır.
#
# Çıktı: 0.09125093 → Model bu görselin Cat olma olasılığını %9.1 olarak tahmin etti.

# %%
import os

test_cat_dir = "/kaggle/working/cats_and_dogs_split/test/Cat"
test_imgs = os.listdir(test_cat_dir)
img_path = os.path.join(test_cat_dir, test_imgs[0])  # klasördeki ilk Cat görseli

# %% [markdown]
# ## Test veri klasöründeki bir kedi görselini alıyoruz.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 1️⃣ ImageDataGenerator ile veri hazırlama
train_dir = "/kaggle/working/cats_and_dogs_split/train"
test_dir = "/kaggle/working/cats_and_dogs_split/test"

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary'
)

# 2️⃣ Functional API ile model tanımlama
inputs = Input(shape=(150,150,3))
x = Conv2D(32, (3,3), activation='relu')(inputs)
x = MaxPooling2D((2,2))(x)
x = Conv2D(64, (3,3), activation='relu')(x)
x = MaxPooling2D((2,2))(x)
x = Conv2D(128, (3,3), activation='relu', name='last_conv')(x)
x = MaxPooling2D((2,2))(x)
x = Flatten()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
outputs = Dense(1, activation='sigmoid')(x)

model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 3️⃣ Modeli eğit
history = model.fit(
    train_generator,
    epochs=5,
    validation_data=test_generator
)
# Out:
# Found 17462 images belonging to 2 classes.
# Found 3743 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 546/546 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.5505 - loss: 0.7276
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 546/546 ━━━━━━━━━━━━━━━━━━━━ 126s 224ms/step - accuracy: 0.5506 - loss: 0.7275 - val_accuracy: 0.6668 - val_loss: 0.6332
# Epoch 2/5
# 546/546 ━━━━━━━━━━━━━━━━━━━━ 120s 220ms/step - accuracy: 0.6333 - loss: 0.6452 - val_accuracy: 0.6476 - val_loss: 0.6475
# Epoch 3/5
# 546/546 ━━━━━━━━━━━━━━━━━━━━ 122s 224ms/step - accuracy: 0.6876 - loss: 0.5891 - val_accuracy: 0.7585 - val_loss: 0.5022
# Epoch 4/5
# 546/546 ━━━━━━━━━━━━━━━━━━━━ 120s 220ms/step - accuracy: 0.7078 - loss: 0.5619 - val_accuracy: 0.7652 - val_loss: 0.4899
# Epoch 5/5
# 546/546 ━━━━━━━━━━━━━━━━━━━━ 121s 221ms/step - accuracy: 0.7336 - loss: 0.5297 - val_accuracy: 0.7521 - val_loss: 0.5207

# %% [markdown]
# Cats vs Dogs Sınıflandırma Projesi
# - 1️ Veri Hazırlama
# ImageDataGenerator ile eğitim ve test verilerini hazırlıyoruz.
# Eğitim verisi için veri artırma (augmentation) uygulandı: döndürme, kaydırma, zoom, yatay çevirme vb.
# Test verisi sadece normalizasyon (rescale) uygulandı.
# - 2️ Model Tanımlama
# Functional API kullanarak basit bir Convolutional Neural Network (CNN) oluşturuldu.
# Katmanlar:
# 3 adet Conv2D + MaxPooling
# Flatten
# Dense katmanı (512 nöron, ReLU)
# Dropout (0.5)
# Çıkış katmanı: 1 nöron, sigmoid (binary sınıflama)
# - 3️ Model Eğitimi
# Model binary_crossentropy loss ve adam optimizer ile derlendi.
# 5 epoch boyunca eğitim ve doğrulama seti ile eğitildi.
# history değişkeni ile eğitim sürecinde loss ve accuracy değerleri takip edildi.

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# Test klasöründeki görsellerden birini al
test_cat_folder = "/kaggle/working/cats_and_dogs_split/test/Cat"
test_images = os.listdir(test_cat_folder)
img_path = os.path.join(test_cat_folder, test_images[0])  # ilk görseli al

# 1️⃣ Görseli yükleme ve diziye çevirme
def get_img_array(img_path, size=(150, 150)):
    img = image.load_img(img_path, target_size=size)
    array = image.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    return array

# 2️⃣ Grad-CAM hesaplama
def make_gradcam_heatmap(img_array, model, last_conv_layer_name="last_conv"):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, 0]

    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# 3️⃣ Grad-CAM görselleştirme
def display_gradcam(img_path, heatmap, alpha=0.4):
    img = image.load_img(img_path)
    img = image.img_to_array(img).astype(np.uint8)

    heatmap = tf.image.resize(heatmap[..., np.newaxis], (img.shape[0], img.shape[1]))
    heatmap = np.uint8(255 * heatmap)
    heatmap = np.repeat(heatmap, 3, axis=-1)

    superimposed_img = img * (1 - alpha) + heatmap * alpha
    superimposed_img = np.uint8(superimposed_img)

    plt.figure(figsize=(6,6))
    plt.imshow(superimposed_img)
    plt.axis("off")
    plt.show()

# 4️⃣ Çalıştır
img_array = get_img_array(img_path)
heatmap = make_gradcam_heatmap(img_array, model)
display_gradcam(img_path, heatmap)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: [['keras_tensor_11']]
# Received: inputs=Tensor(shape=(1, 150, 150, 3))
#   warnings.warn(msg)
# /tmp/ipykernel_36/3647933069.py:44: RuntimeWarning: invalid value encountered in cast
#   heatmap = np.uint8(255 * heatmap)

# %% [markdown]
# ## Tek Görsel için Grad-CAM Uygulaması¶
# -  Test Görselini Hazırlama
# Test klasöründen bir kedi görseli seçildi.
# get_img_array fonksiyonu ile görsel 150x150 boyutuna ölçeklendi ve array'e çevrildi.
# -  Grad-CAM Hesaplama
# make_gradcam_heatmap fonksiyonu:
# Modelin son Conv2D katmanının çıktısını ve tahminini alıyor.
# Grad-CAM algoritması ile görselin hangi bölgelerinin tahminde etkili olduğunu belirliyor.
# Çıktı olarak 0-1 aralığında bir heatmap üretiyor.
# -  Grad-CAM Görselleştirme
# display_gradcam fonksiyonu:
# Orijinal görsel ile heatmap’i birleştiriyor.
# Sonucu matplotlib ile ekranda gösteriyor.
# -  Çalıştırma
# Seçilen görsel array'e çevrilip Grad-CAM heatmap'i oluşturuldu ve görselleştirildi.

# %%
import os

test_cat_folder = "/kaggle/working/cats_and_dogs_split/test/Cat"
# Test klasöründeki ilk görseli seç
img_file = os.listdir(test_cat_folder)[0]
img_path = os.path.join(test_cat_folder, img_file)

# Sonra Grad-CAM kodunu kullanabiliriz
img_array = get_img_array(img_path)
heatmap = make_gradcam_heatmap(img_array, model)
display_gradcam(img_path, heatmap)
# Out:
# /tmp/ipykernel_36/3647933069.py:44: RuntimeWarning: invalid value encountered in cast
#   heatmap = np.uint8(255 * heatmap)

# %% [markdown]
# ## Tek Görsel Seçimi ve Grad-CAM Uygulama
# Test klasöründen ilk kedi görseli seçildi.
# get_img_array ile görsel array'e çevrildi.
# make_gradcam_heatmap ile heatmap hesaplandı.
# display_gradcam ile görsel üzerine heatmap uygulanıp gösterildi.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing import image

# Test klasörleri
test_folder = "/kaggle/working/cats_and_dogs_split/test"
output_folder = "/kaggle/working/gradcam_results"

# Klasörleri oluştur
for category in ["Cat", "Dog"]:
    os.makedirs(os.path.join(output_folder, category), exist_ok=True)

def get_img_array(img_path, target_size=(150,150)):
    img = image.load_img(img_path, target_size=target_size)
    array = image.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    array = array / 255.0
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name="last_conv"):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, 0]
    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = tf.reduce_mean(tf.multiply(conv_outputs, pooled_grads), axis=-1)
    heatmap = np.maximum(heatmap, 0)
    heatmap /= tf.reduce_max(heatmap) if tf.reduce_max(heatmap) != 0 else 1
    heatmap = np.uint8(255 * heatmap)
    return heatmap

def display_gradcam(img_path, heatmap, alpha=0.4):
    img = image.load_img(img_path)
    img = image.img_to_array(img).astype(np.uint8)
    heatmap = np.expand_dims(heatmap, axis=-1)
    heatmap = np.repeat(heatmap, 3, axis=-1)
    superimposed_img = heatmap * alpha + img
    superimposed_img = np.clip(superimposed_img, 0, 255).astype(np.uint8)
    return superimposed_img

# Burada model değişkenini doğrudan kullanıyoruz, tekrar load_model yok
for category in ["Cat", "Dog"]:
    category_folder = os.path.join(test_folder, category)
    for img_file in os.listdir(category_folder):
        img_path = os.path.join(category_folder, img_file)
        try:
            img_array = get_img_array(img_path)
            heatmap = make_gradcam_heatmap(img_array, model)
            superimposed_img = display_gradcam(img_path, heatmap)
            
            save_path = os.path.join(output_folder, category, img_file)
            plt.imsave(save_path, superimposed_img)
        except Exception as e:
            print(f"Atlandı: {img_path} ({e})")
            continue

print("Tüm test görselleri için Grad-CAM oluşturuldu ve kaydedildi.")
# Out:
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/407.jpg (operands could not be broadcast together with shapes (34,34,3) (289,288,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7380.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7736.jpg (operands could not be broadcast together with shapes (34,34,3) (500,476,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5608.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1062.jpg (operands could not be broadcast together with shapes (34,34,3) (360,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4939.jpg (operands could not be broadcast together with shapes (34,34,3) (262,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8551.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6360.jpg (operands could not be broadcast together with shapes (34,34,3) (394,387,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11778.jpg (operands could not be broadcast together with shapes (34,34,3) (200,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5115.jpg (operands could not be broadcast together with shapes (34,34,3) (298,346,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4827.jpg (operands could not be broadcast together with shapes (34,34,3) (500,332,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6244.jpg (operands could not be broadcast together with shapes (34,34,3) (360,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/412.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10191.jpg (operands could not be broadcast together with shapes (34,34,3) (312,468,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8935.jpg (operands could not be broadcast together with shapes (34,34,3) (121,88,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8151.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10425.jpg (operands could not be broadcast together with shapes (34,34,3) (500,363,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4247.jpg (operands could not be broadcast together with shapes (34,34,3) (500,392,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5595.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6339.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11570.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9423.jpg (operands could not be broadcast together with shapes (34,34,3) (251,270,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/914.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8585.jpg (operands could not be broadcast together with shapes (34,34,3) (70,94,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5262.jpg (operands could not be broadcast together with shapes (34,34,3) (500,357,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9431.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3429.jpg (operands could not be broadcast together with shapes (34,34,3) (257,209,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9149.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4419.jpg (operands could not be broadcast together with shapes (34,34,3) (316,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10112.jpg (operands could not be broadcast together with shapes (34,34,3) (470,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9952.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5429.jpg (operands could not be broadcast together with shapes (34,34,3) (460,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12243.jpg (operands could not be broadcast together with shapes (34,34,3) (145,423,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2155.jpg (operands could not be broadcast together with shapes (34,34,3) (500,436,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2069.jpg (operands could not be broadcast together with shapes (34,34,3) (319,250,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2292.jpg (operands could not be broadcast together with shapes (34,34,3) (328,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1891.jpg (operands could not be broadcast together with shapes (34,34,3) (292,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2704.jpg (operands could not be broadcast together with shapes (34,34,3) (281,188,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10509.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11884.jpg (operands could not be broadcast together with shapes (34,34,3) (354,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12471.jpg (operands could not be broadcast together with shapes (34,34,3) (189,252,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8590.jpg (operands could not be broadcast together with shapes (34,34,3) (245,188,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7446.jpg (operands could not be broadcast together with shapes (34,34,3) (469,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10341.jpg (operands could not be broadcast together with shapes (34,34,3) (213,240,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6910.jpg (operands could not be broadcast together with shapes (34,34,3) (288,432,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4029.jpg (operands could not be broadcast together with shapes (34,34,3) (140,121,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6654.jpg (operands could not be broadcast together with shapes (34,34,3) (413,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11006.jpg (operands could not be broadcast together with shapes (34,34,3) (225,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8891.jpg (operands could not be broadcast together with shapes (34,34,3) (402,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/491.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5605.jpg (operands could not be broadcast together with shapes (34,34,3) (500,462,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10247.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11864.jpg (operands could not be broadcast together with shapes (34,34,3) (235,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2969.jpg (operands could not be broadcast together with shapes (34,34,3) (424,458,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10449.jpg (operands could not be broadcast together with shapes (34,34,3) (404,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5104.jpg (operands could not be broadcast together with shapes (34,34,3) (432,317,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10367.jpg (operands could not be broadcast together with shapes (34,34,3) (500,442,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8024.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7529.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10009.jpg (operands could not be broadcast together with shapes (34,34,3) (500,473,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11344.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4130.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/371.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4664.jpg (operands could not be broadcast together with shapes (34,34,3) (209,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8193.jpg (operands could not be broadcast together with shapes (34,34,3) (500,294,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5907.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8866.jpg (operands could not be broadcast together with shapes (34,34,3) (144,176,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6869.jpg (operands could not be broadcast together with shapes (34,34,3) (335,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2520.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6533.jpg (operands could not be broadcast together with shapes (34,34,3) (425,450,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7006.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8727.jpg (operands could not be broadcast together with shapes (34,34,3) (362,285,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4248.jpg (operands could not be broadcast together with shapes (34,34,3) (384,478,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2836.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3162.jpg (operands could not be broadcast together with shapes (34,34,3) (374,499,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/934.jpg (operands could not be broadcast together with shapes (34,34,3) (137,180,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2296.jpg (operands could not be broadcast together with shapes (34,34,3) (360,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/587.jpg (operands could not be broadcast together with shapes (34,34,3) (240,255,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9004.jpg (operands could not be broadcast together with shapes (34,34,3) (324,321,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6666.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5325.jpg (operands could not be broadcast together with shapes (34,34,3) (377,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/687.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5828.jpg (operands could not be broadcast together with shapes (34,34,3) (434,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11160.jpg (operands could not be broadcast together with shapes (34,34,3) (468,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11299.jpg (operands could not be broadcast together with shapes (34,34,3) (500,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4519.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10548.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10290.jpg (operands could not be broadcast together with shapes (34,34,3) (500,448,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10476.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1587.jpg (operands could not be broadcast together with shapes (34,34,3) (312,468,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10118.jpg (operands could not be broadcast together with shapes (34,34,3) (424,438,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3400.jpg (operands could not be broadcast together with shapes (34,34,3) (288,286,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3614.jpg (operands could not be broadcast together with shapes (34,34,3) (500,355,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6687.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12050.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6027.jpg (operands could not be broadcast together with shapes (34,34,3) (379,423,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1158.jpg (operands could not be broadcast together with shapes (34,34,3) (390,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5855.jpg (operands could not be broadcast together with shapes (34,34,3) (500,332,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3102.jpg (operands could not be broadcast together with shapes (34,34,3) (292,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5796.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2295.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1012.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5518.jpg (operands could not be broadcast together with shapes (34,34,3) (270,360,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10098.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9.jpg (operands could not be broadcast together with shapes (34,34,3) (426,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9391.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9923.jpg (operands could not be broadcast together with shapes (34,34,3) (500,308,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7755.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6110.jpg (operands could not be broadcast together with shapes (34,34,3) (262,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9492.jpg (operands could not be broadcast together with shapes (34,34,3) (334,298,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10749.jpg (operands could not be broadcast together with shapes (34,34,3) (405,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4600.jpg (operands could not be broadcast together with shapes (34,34,3) (336,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4629.jpg (operands could not be broadcast together with shapes (34,34,3) (75,100,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4538.jpg (operands could not be broadcast together with shapes (34,34,3) (500,333,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5469.jpg (operands could not be broadcast together with shapes (34,34,3) (296,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10927.jpg (operands could not be broadcast together with shapes (34,34,3) (359,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6263.jpg (operands could not be broadcast together with shapes (34,34,3) (115,113,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3563.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11552.jpg (operands could not be broadcast together with shapes (34,34,3) (200,250,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6204.jpg (operands could not be broadcast together with shapes (34,34,3) (368,482,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4242.jpg (operands could not be broadcast together with shapes (34,34,3) (479,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10094.jpg (operands could not be broadcast together with shapes (34,34,3) (216,288,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7792.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10949.jpg (operands could not be broadcast together with shapes (34,34,3) (300,247,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3865.jpg (operands could not be broadcast together with shapes (34,34,3) (240,307,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2058.jpg (operands could not be broadcast together with shapes (34,34,3) (500,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10552.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/342.jpg (operands could not be broadcast together with shapes (34,34,3) (153,160,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10584.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9364.jpg (operands could not be broadcast together with shapes (34,34,3) (350,293,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/571.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/753.jpg (operands could not be broadcast together with shapes (34,34,3) (422,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9519.jpg (operands could not be broadcast together with shapes (34,34,3) (288,277,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10617.jpg (operands could not be broadcast together with shapes (34,34,3) (300,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12484.jpg (operands could not be broadcast together with shapes (34,34,3) (500,498,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9385.jpg (operands could not be broadcast together with shapes (34,34,3) (336,448,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9258.jpg (operands could not be broadcast together with shapes (34,34,3) (320,202,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/568.jpg (operands could not be broadcast together with shapes (34,34,3) (328,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7912.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5928.jpg (operands could not be broadcast together with shapes (34,34,3) (112,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1372.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6252.jpg (operands could not be broadcast together with shapes (34,34,3) (481,376,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2112.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10541.jpg (operands could not be broadcast together with shapes (34,34,3) (227,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1560.jpg (operands could not be broadcast together with shapes (34,34,3) (201,288,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11357.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10626.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1896.jpg (operands could not be broadcast together with shapes (34,34,3) (336,448,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9773.jpg (operands could not be broadcast together with shapes (34,34,3) (242,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11677.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6889.jpg (operands could not be broadcast together with shapes (34,34,3) (484,416,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3368.jpg (operands could not be broadcast together with shapes (34,34,3) (372,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2196.jpg (operands could not be broadcast together with shapes (34,34,3) (500,390,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2064.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10203.jpg (operands could not be broadcast together with shapes (34,34,3) (258,175,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8599.jpg (operands could not be broadcast together with shapes (34,34,3) (459,490,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7659.jpg (operands could not be broadcast together with shapes (34,34,3) (252,212,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3101.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12401.jpg (operands could not be broadcast together with shapes (34,34,3) (475,371,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11097.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9931.jpg (operands could not be broadcast together with shapes (34,34,3) (500,482,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8542.jpg (operands could not be broadcast together with shapes (34,34,3) (186,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8862.jpg (operands could not be broadcast together with shapes (34,34,3) (500,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1196.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9202.jpg (operands could not be broadcast together with shapes (34,34,3) (355,288,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2424.jpg (operands could not be broadcast together with shapes (34,34,3) (152,250,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8218.jpg (operands could not be broadcast together with shapes (34,34,3) (300,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7299.jpg (operands could not be broadcast together with shapes (34,34,3) (213,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10975.jpg (operands could not be broadcast together with shapes (34,34,3) (212,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9543.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9288.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3645.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2256.jpg (operands could not be broadcast together with shapes (34,34,3) (336,448,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3687.jpg (operands could not be broadcast together with shapes (34,34,3) (500,412,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11917.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3069.jpg (operands could not be broadcast together with shapes (34,34,3) (225,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1723.jpg (operands could not be broadcast together with shapes (34,34,3) (500,216,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7756.jpg (operands could not be broadcast together with shapes (34,34,3) (321,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11700.jpg (operands could not be broadcast together with shapes (34,34,3) (296,257,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/867.jpg (operands could not be broadcast together with shapes (34,34,3) (266,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11171.jpg (operands could not be broadcast together with shapes (34,34,3) (235,314,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10220.jpg (operands could not be broadcast together with shapes (34,34,3) (300,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8579.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12280.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7236.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4971.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7515.jpg (operands could not be broadcast together with shapes (34,34,3) (332,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2147.jpg (operands could not be broadcast together with shapes (34,34,3) (500,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9927.jpg (operands could not be broadcast together with shapes (34,34,3) (188,139,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6493.jpg (operands could not be broadcast together with shapes (34,34,3) (260,346,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8572.jpg (operands could not be broadcast together with shapes (34,34,3) (350,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1967.jpg (operands could not be broadcast together with shapes (34,34,3) (302,341,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11639.jpg (operands could not be broadcast together with shapes (34,34,3) (500,437,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4937.jpg (operands could not be broadcast together with shapes (34,34,3) (500,499,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2126.jpg (operands could not be broadcast together with shapes (34,34,3) (500,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11519.jpg (operands could not be broadcast together with shapes (34,34,3) (500,429,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3606.jpg (operands could not be broadcast together with shapes (34,34,3) (360,479,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5750.jpg (operands could not be broadcast together with shapes (34,34,3) (118,140,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/761.jpg (operands could not be broadcast together with shapes (34,34,3) (200,151,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9380.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8577.jpg (operands could not be broadcast together with shapes (34,34,3) (259,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11846.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11562.jpg (operands could not be broadcast together with shapes (34,34,3) (100,190,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1768.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5698.jpg (operands could not be broadcast together with shapes (34,34,3) (427,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1689.jpg (operands could not be broadcast together with shapes (34,34,3) (470,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10296.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8738.jpg (operands could not be broadcast together with shapes (34,34,3) (347,399,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4264.jpg (operands could not be broadcast together with shapes (34,34,3) (323,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2340.jpg (operands could not be broadcast together with shapes (34,34,3) (359,479,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6034.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3261.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5591.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6810.jpg (operands could not be broadcast together with shapes (34,34,3) (363,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5213.jpg (operands could not be broadcast together with shapes (34,34,3) (341,482,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1655.jpg (operands could not be broadcast together with shapes (34,34,3) (420,352,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1945.jpg (operands could not be broadcast together with shapes (34,34,3) (500,490,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2171.jpg (operands could not be broadcast together with shapes (34,34,3) (371,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1270.jpg (operands could not be broadcast together with shapes (34,34,3) (427,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1769.jpg (operands could not be broadcast together with shapes (34,34,3) (373,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4643.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10921.jpg (operands could not be broadcast together with shapes (34,34,3) (254,227,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3686.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9685.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9020.jpg (operands could not be broadcast together with shapes (34,34,3) (413,431,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1336.jpg (operands could not be broadcast together with shapes (34,34,3) (500,407,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7350.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1519.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9386.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8066.jpg (operands could not be broadcast together with shapes (34,34,3) (430,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9168.jpg (operands could not be broadcast together with shapes (34,34,3) (331,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11381.jpg (operands could not be broadcast together with shapes (34,34,3) (238,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9511.jpg (operands could not be broadcast together with shapes (34,34,3) (357,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6039.jpg (operands could not be broadcast together with shapes (34,34,3) (185,172,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8885.jpg (operands could not be broadcast together with shapes (34,34,3) (401,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8116.jpg (operands could not be broadcast together with shapes (34,34,3) (275,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2749.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/493.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11104.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6056.jpg (operands could not be broadcast together with shapes (34,34,3) (188,192,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12382.jpg (operands could not be broadcast together with shapes (34,34,3) (357,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10334.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1251.jpg (operands could not be broadcast together with shapes (34,34,3) (220,333,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11987.jpg (operands could not be broadcast together with shapes (34,34,3) (482,365,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/273.jpg (operands could not be broadcast together with shapes (34,34,3) (117,180,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5043.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5529.jpg (operands could not be broadcast together with shapes (34,34,3) (100,150,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10251.jpg (operands could not be broadcast together with shapes (34,34,3) (486,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3840.jpg (operands could not be broadcast together with shapes (34,34,3) (338,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9980.jpg (operands could not be broadcast together with shapes (34,34,3) (500,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12384.jpg (operands could not be broadcast together with shapes (34,34,3) (179,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5040.jpg (operands could not be broadcast together with shapes (34,34,3) (500,407,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8735.jpg (operands could not be broadcast together with shapes (34,34,3) (313,448,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1588.jpg (operands could not be broadcast together with shapes (34,34,3) (256,256,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10256.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2450.jpg (operands could not be broadcast together with shapes (34,34,3) (385,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/876.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7206.jpg (operands could not be broadcast together with shapes (34,34,3) (262,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4898.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5810.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7174.jpg (operands could not be broadcast together with shapes (34,34,3) (500,447,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7147.jpg (operands could not be broadcast together with shapes (34,34,3) (500,332,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11604.jpg (operands could not be broadcast together with shapes (34,34,3) (148,136,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1872.jpg (operands could not be broadcast together with shapes (34,34,3) (379,396,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10479.jpg (operands could not be broadcast together with shapes (34,34,3) (282,372,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4962.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10228.jpg (operands could not be broadcast together with shapes (34,34,3) (251,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8686.jpg (operands could not be broadcast together with shapes (34,34,3) (361,227,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6336.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1584.jpg (operands could not be broadcast together with shapes (34,34,3) (270,283,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1232.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5732.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8719.jpg (operands could not be broadcast together with shapes (34,34,3) (348,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6271.jpg (operands could not be broadcast together with shapes (34,34,3) (235,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3114.jpg (operands could not be broadcast together with shapes (34,34,3) (360,216,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8573.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3259.jpg (operands could not be broadcast together with shapes (34,34,3) (500,450,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9871.jpg (operands could not be broadcast together with shapes (34,34,3) (338,450,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10302.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6559.jpg (operands could not be broadcast together with shapes (34,34,3) (381,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11814.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8939.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10732.jpg (operands could not be broadcast together with shapes (34,34,3) (299,357,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2552.jpg (operands could not be broadcast together with shapes (34,34,3) (500,479,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9494.jpg (operands could not be broadcast together with shapes (34,34,3) (150,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7230.jpg (operands could not be broadcast together with shapes (34,34,3) (329,431,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11109.jpg (operands could not be broadcast together with shapes (34,34,3) (105,140,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10363.jpg (operands could not be broadcast together with shapes (34,34,3) (400,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12218.jpg (operands could not be broadcast together with shapes (34,34,3) (361,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11888.jpg (operands could not be broadcast together with shapes (34,34,3) (500,481,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3829.jpg (operands could not be broadcast together with shapes (34,34,3) (500,277,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5186.jpg (operands could not be broadcast together with shapes (34,34,3) (415,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10466.jpg (operands could not be broadcast together with shapes (34,34,3) (253,220,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6447.jpg (operands could not be broadcast together with shapes (34,34,3) (250,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10260.jpg (operands could not be broadcast together with shapes (34,34,3) (500,281,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7712.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9779.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4249.jpg (operands could not be broadcast together with shapes (34,34,3) (262,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11466.jpg (operands could not be broadcast together with shapes (34,34,3) (192,149,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5329.jpg (operands could not be broadcast together with shapes (34,34,3) (500,402,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7459.jpg (operands could not be broadcast together with shapes (34,34,3) (270,360,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9141.jpg (operands could not be broadcast together with shapes (34,34,3) (448,336,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2416.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8117.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4464.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8765.jpg (operands could not be broadcast together with shapes (34,34,3) (390,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8857.jpg (operands could not be broadcast together with shapes (34,34,3) (352,384,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8595.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3393.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7295.jpg (operands could not be broadcast together with shapes (34,34,3) (499,346,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10709.jpg (operands could not be broadcast together with shapes (34,34,3) (339,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1992.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/419.jpg (operands could not be broadcast together with shapes (34,34,3) (480,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10614.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1767.jpg (operands could not be broadcast together with shapes (34,34,3) (499,476,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3439.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3871.jpg (operands could not be broadcast together with shapes (34,34,3) (200,173,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2597.jpg (operands could not be broadcast together with shapes (34,34,3) (225,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4034.jpg (operands could not be broadcast together with shapes (34,34,3) (500,328,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5200.jpg (operands could not be broadcast together with shapes (34,34,3) (290,387,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3359.jpg (operands could not be broadcast together with shapes (34,34,3) (500,388,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8743.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9324.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7323.jpg (operands could not be broadcast together with shapes (34,34,3) (200,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3914.jpg (operands could not be broadcast together with shapes (34,34,3) (360,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4885.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4846.jpg (operands could not be broadcast together with shapes (34,34,3) (188,141,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9251.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11894.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7953.jpg (operands could not be broadcast together with shapes (34,34,3) (500,365,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2530.jpg (operands could not be broadcast together with shapes (34,34,3) (374,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7565.jpg (operands could not be broadcast together with shapes (34,34,3) (500,382,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/791.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2418.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1739.jpg (operands could not be broadcast together with shapes (34,34,3) (226,343,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9895.jpg (operands could not be broadcast together with shapes (34,34,3) (500,410,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1054.jpg (operands could not be broadcast together with shapes (34,34,3) (311,311,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5427.jpg (operands could not be broadcast together with shapes (34,34,3) (300,448,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3652.jpg (operands could not be broadcast together with shapes (34,34,3) (380,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/670.jpg (operands could not be broadcast together with shapes (34,34,3) (332,500,3) )
# ...
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2958.jpg (operands could not be broadcast together with shapes (34,34,3) (180,141,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4223.jpg (operands could not be broadcast together with shapes (34,34,3) (415,242,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11285.jpg (operands could not be broadcast together with shapes (34,34,3) (256,234,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/12035.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5237.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3061.jpg (operands could not be broadcast together with shapes (34,34,3) (200,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2016.jpg (operands could not be broadcast together with shapes (34,34,3) (479,454,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6098.jpg (operands could not be broadcast together with shapes (34,34,3) (457,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5348.jpg (operands could not be broadcast together with shapes (34,34,3) (400,319,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8616.jpg (operands could not be broadcast together with shapes (34,34,3) (282,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/341.jpg (operands could not be broadcast together with shapes (34,34,3) (500,443,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5637.jpg (operands could not be broadcast together with shapes (34,34,3) (239,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7148.jpg (operands could not be broadcast together with shapes (34,34,3) (500,323,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4341.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/122.jpg (operands could not be broadcast together with shapes (34,34,3) (263,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7854.jpg (operands could not be broadcast together with shapes (34,34,3) (448,336,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8449.jpg (operands could not be broadcast together with shapes (34,34,3) (192,288,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7204.jpg (operands could not be broadcast together with shapes (34,34,3) (485,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4230.jpg (operands could not be broadcast together with shapes (34,34,3) (314,360,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10078.jpg (operands could not be broadcast together with shapes (34,34,3) (500,456,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2501.jpg (operands could not be broadcast together with shapes (34,34,3) (301,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11432.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4183.jpg (operands could not be broadcast together with shapes (34,34,3) (300,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3354.jpg (operands could not be broadcast together with shapes (34,34,3) (152,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2581.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2446.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4220.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11806.jpg (operands could not be broadcast together with shapes (34,34,3) (455,288,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5636.jpg (operands could not be broadcast together with shapes (34,34,3) (377,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4576.jpg (operands could not be broadcast together with shapes (34,34,3) (350,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10736.jpg (operands could not be broadcast together with shapes (34,34,3) (401,343,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1776.jpg (operands could not be broadcast together with shapes (34,34,3) (438,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5443.jpg (operands could not be broadcast together with shapes (34,34,3) (500,417,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3582.jpg (operands could not be broadcast together with shapes (34,34,3) (498,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10115.jpg (operands could not be broadcast together with shapes (34,34,3) (163,180,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9610.jpg (operands could not be broadcast together with shapes (34,34,3) (400,258,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10288.jpg (operands could not be broadcast together with shapes (34,34,3) (285,227,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/12331.jpg (operands could not be broadcast together with shapes (34,34,3) (73,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6312.jpg (operands could not be broadcast together with shapes (34,34,3) (269,299,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7093.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11561.jpg (operands could not be broadcast together with shapes (34,34,3) (500,491,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8396.jpg (operands could not be broadcast together with shapes (34,34,3) (252,159,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9572.jpg (operands could not be broadcast together with shapes (34,34,3) (400,285,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3929.jpg (operands could not be broadcast together with shapes (34,34,3) (480,456,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4301.jpg (operands could not be broadcast together with shapes (34,34,3) (104,140,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10374.jpg (operands could not be broadcast together with shapes (34,34,3) (374,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10738.jpg (operands could not be broadcast together with shapes (34,34,3) (300,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3263.jpg (operands could not be broadcast together with shapes (34,34,3) (458,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3247.jpg (operands could not be broadcast together with shapes (34,34,3) (292,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/12169.jpg (operands could not be broadcast together with shapes (34,34,3) (191,120,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6999.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1151.jpg (operands could not be broadcast together with shapes (34,34,3) (200,319,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1874.jpg (operands could not be broadcast together with shapes (34,34,3) (225,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9570.jpg (operands could not be broadcast together with shapes (34,34,3) (171,141,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7721.jpg (operands could not be broadcast together with shapes (34,34,3) (500,354,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7233.jpg (operands could not be broadcast together with shapes (34,34,3) (224,299,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10320.jpg (operands could not be broadcast together with shapes (34,34,3) (476,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/12057.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7278.jpg (operands could not be broadcast together with shapes (34,34,3) (350,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7899.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8018.jpg (operands could not be broadcast together with shapes (34,34,3) (400,408,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6423.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8191.jpg (operands could not be broadcast together with shapes (34,34,3) (496,297,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3191.jpg (operands could not be broadcast together with shapes (34,34,3) (349,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9562.jpg (operands could not be broadcast together with shapes (34,34,3) (285,380,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5306.jpg (operands could not be broadcast together with shapes (34,34,3) (500,396,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2227.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4902.jpg (operands could not be broadcast together with shapes (34,34,3) (406,371,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7065.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3826.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3117.jpg (operands could not be broadcast together with shapes (34,34,3) (470,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6653.jpg (operands could not be broadcast together with shapes (34,34,3) (250,170,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4929.jpg (operands could not be broadcast together with shapes (34,34,3) (176,216,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5606.jpg (operands could not be broadcast together with shapes (34,34,3) (150,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10955.jpg (operands could not be broadcast together with shapes (34,34,3) (410,275,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11396.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10644.jpg (operands could not be broadcast together with shapes (34,34,3) (334,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9005.jpg (operands could not be broadcast together with shapes (34,34,3) (391,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6373.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6729.jpg (operands could not be broadcast together with shapes (34,34,3) (233,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6220.jpg (operands could not be broadcast together with shapes (34,34,3) (362,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7026.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/689.jpg (operands could not be broadcast together with shapes (34,34,3) (500,485,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7959.jpg (operands could not be broadcast together with shapes (34,34,3) (352,279,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2360.jpg (operands could not be broadcast together with shapes (34,34,3) (448,319,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/12308.jpg (operands could not be broadcast together with shapes (34,34,3) (360,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11301.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10292.jpg (operands could not be broadcast together with shapes (34,34,3) (303,144,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8019.jpg (operands could not be broadcast together with shapes (34,34,3) (500,451,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/362.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5569.jpg (operands could not be broadcast together with shapes (34,34,3) (345,284,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11011.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11247.jpg (operands could not be broadcast together with shapes (34,34,3) (193,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9683.jpg (operands could not be broadcast together with shapes (34,34,3) (360,270,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1928.jpg (operands could not be broadcast together with shapes (34,34,3) (215,280,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/489.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6483.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1285.jpg (operands could not be broadcast together with shapes (34,34,3) (500,390,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9723.jpg (operands could not be broadcast together with shapes (34,34,3) (480,402,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10544.jpg (operands could not be broadcast together with shapes (34,34,3) (288,336,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4988.jpg (operands could not be broadcast together with shapes (34,34,3) (382,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6744.jpg (operands could not be broadcast together with shapes (34,34,3) (478,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2462.jpg (operands could not be broadcast together with shapes (34,34,3) (470,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/956.jpg (operands could not be broadcast together with shapes (34,34,3) (188,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1592.jpg (operands could not be broadcast together with shapes (34,34,3) (364,301,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5653.jpg (operands could not be broadcast together with shapes (34,34,3) (232,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1785.jpg (operands could not be broadcast together with shapes (34,34,3) (387,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4133.jpg (operands could not be broadcast together with shapes (34,34,3) (383,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6639.jpg (operands could not be broadcast together with shapes (34,34,3) (500,423,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/270.jpg (operands could not be broadcast together with shapes (34,34,3) (401,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8991.jpg (operands could not be broadcast together with shapes (34,34,3) (375,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10753.jpg (operands could not be broadcast together with shapes (34,34,3) (389,428,3) )
# Tüm test görselleri için Grad-CAM oluşturuldu ve kaydedildi.

# %% [markdown]
# ## Tüm Test Görselleri için Grad-CAM Oluşturma ve Kaydetme
# Test klasöründeki "Cat" ve "Dog" kategorilerindeki tüm görseller için Grad-CAM hesaplandı.
# get_img_array ile görseller array'e dönüştürüldü.
# make_gradcam_heatmap ile heatmap oluşturuldu.
# display_gradcam ile heatmap görselin üzerine uygulandı.
# Sonuçlar gradcam_results klasörüne kaydedildi.
# Hatalı veya bozuk görseller atlandı.

# %%
import matplotlib.pyplot as plt

# Eğitim & Doğrulama Accuracy grafiği
plt.figure(figsize=(8,6))
plt.plot(history.history['accuracy'], label='Eğitim Accuracy')
plt.plot(history.history['val_accuracy'], label='Doğrulama Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Eğitim & Doğrulama Loss grafiği
plt.figure(figsize=(8,6))
plt.plot(history.history['loss'], label='Eğitim Loss')
plt.plot(history.history['val_loss'], label='Doğrulama Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Modelin Eğitim Performans Grafikleri
# Accuracy Grafiği: Eğitim ve doğrulama accuracy değerlerinin epochlara göre değişimi.
# Loss Grafiği: Eğitim ve doğrulama kayıp (loss) değerlerinin epochlara göre değişimi.
# Bu grafikler modelin öğrenme sürecini görselleştirir ve overfitting veya underfitting durumlarını gözlemlemeye yardımcı olur.

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Test verisini yeniden yükle (ImageDataGenerator ile)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    "/kaggle/working/cats_and_dogs_split/test",
    target_size=(150,150),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)

# Modeli test setinde değerlendir
loss, acc = model.evaluate(test_generator, verbose=1)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {acc:.4f}")

# Tahminler
y_pred = model.predict(test_generator)
y_pred_classes = (y_pred > 0.5).astype("int32")
y_true = test_generator.classes

# Karışıklık matrisi
cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel("Tahmin")
plt.ylabel("Gerçek")
plt.title("Karışıklık Matrisi")
plt.show()

# Sınıflandırma raporu
print("\nSınıflandırma Raporu:\n")
print(classification_report(y_true, y_pred_classes, target_names=test_generator.class_indices.keys()))
# Out:
# Found 3743 images belonging to 2 classes.
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - accuracy: 0.6489 - loss: 0.6968
# Test Loss: 0.5207
# Test Accuracy: 0.7521
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step
# Sınıflandırma Raporu:
#
#               precision    recall  f1-score   support
#
#          Cat       0.84      0.62      0.71      1872
#          Dog       0.70      0.88      0.78      1871
#
#     accuracy                           0.75      3743
#    macro avg       0.77      0.75      0.75      3743
# weighted avg       0.77      0.75      0.75      3743

# %% [markdown]
# ### Model Değerlendirme: Test Verisi¶
# Test Loss ve Accuracy: Modelin test setindeki performansını özetler.
# Karışıklık Matrisi (Confusion Matrix): Modelin hangi sınıfları doğru veya yanlış tahmin ettiğini görselleştirir.
# Sınıflandırma Raporu (Classification Report): Precision, recall ve F1-score değerleri ile sınıf bazlı performansı özetler.
# Bu adım modelin gerçek veri üzerindeki doğruluğunu ve sınıflara göre başarısını incelemeye yarar.
