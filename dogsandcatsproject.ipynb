# %%
import os

base_path = "/kaggle/input"
for root, dirs, files in os.walk(base_path):
    print(root, len(files))
# Out:
# /kaggle/input 0
# /kaggle/input/microsoft-catsvsdogs-dataset 2
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages 0
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog 12501
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat 12501

# %% [markdown]
# ## Veri Klasör Yapısını Görüntüleme
#
# Bu kod, `/kaggle/input` klasörü altındaki tüm dizinleri ve her dizindeki dosya sayısını listeler.
# Amaç, veri setinin klasör yapısını ve içindeki dosya sayısını hızlıca kontrol etmektir.

# %%
import os

base_path = "/kaggle/input"
for root, dirs, files in os.walk(base_path):
    print(root, "->", len(files), "dosya")
# Out:
# /kaggle/input -> 0 dosya
# /kaggle/input/microsoft-catsvsdogs-dataset -> 2 dosya
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages -> 0 dosya
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog -> 12501 dosya
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat -> 12501 dosya

# %% [markdown]
# ## Veri Klasör Yapısını Kontrol Etme
#
# Bu kod, `/kaggle/input` klasörü altındaki tüm dizinleri ve her dizinde kaç dosya olduğunu listeler.
# Amaç, veri setinin doğru şekilde yüklendiğini ve dosya sayısını kontrol etmektir.
#
# ```python

# %%
import os, cv2

cat_dir = "/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat"
dog_dir = "/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog"

def clean_images(folder):
    bad_files = []
    for file in os.listdir(folder):
        path = os.path.join(folder, file)
        try:
            img = cv2.imread(path)
            if img is None:
                bad_files.append(path)
        except:
            bad_files.append(path)
    return bad_files

bad_cats = clean_images(cat_dir)
bad_dogs = clean_images(dog_dir)

print("Bozuk kedi resimleri:", bad_cats)
print("Bozuk köpek resimleri:", bad_dogs)
# Out:
# Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# Warning: unknown JFIF revision number 0.00
# Corrupt JPEG data: 254 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1403 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 2230 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# Bozuk kedi resimleri: ['/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/4833.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/850.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/8470.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/11210.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/660.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/140.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/10820.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/10501.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/9171.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/9778.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/2663.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/11935.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/10125.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/11874.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/936.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/Thumbs.db', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/5553.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/7978.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/3491.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/3300.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/666.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/7968.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/11565.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/10404.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/9565.jpg']
# Bozuk köpek resimleri: ['/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/6059.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11849.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/3288.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/6238.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/2688.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7112.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/8730.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11702.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7133.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11853.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7969.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7459.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/10747.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/6718.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/2877.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/3136.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11675.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/4367.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/Thumbs.db', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/5604.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/9188.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/3588.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11410.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/1308.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/10158.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/2384.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/1866.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7369.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/10797.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/10401.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/5736.jpg']

# %% [markdown]
# ### Bu hücre, veri setindeki bozuk veya açılamayan resimleri tespit eder. Sonuç olarak, bozuk resimler ekrana yazdırılır ve sonraki adımlarda bu dosyalar silinebilir.

# %%
import os
import cv2
import shutil

# Orijinal veri seti dizinleri
cat_dir = "/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat"
dog_dir = "/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog"

# Temiz veri seti için yeni klasör
clean_base = "/kaggle/working/cats_and_dogs_clean"
os.makedirs(clean_base, exist_ok=True)

def copy_good_images(src_folder, dest_folder):
    os.makedirs(dest_folder, exist_ok=True)
    for file in os.listdir(src_folder):
        src_path = os.path.join(src_folder, file)
        try:
            img = cv2.imread(src_path)
            if img is not None:
                shutil.copy(src_path, dest_folder)
        except:
            continue

# Kedi ve köpek resimlerini temiz klasöre kopyala
copy_good_images(cat_dir, os.path.join(clean_base, "Cat"))
copy_good_images(dog_dir, os.path.join(clean_base, "Dog"))

print("Temiz veri klasörü hazır:", clean_base)
# Out:
# Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# Warning: unknown JFIF revision number 0.00
# Corrupt JPEG data: 254 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1403 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 2230 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# Temiz veri klasörü hazır: /kaggle/working/cats_and_dogs_clean

# %% [markdown]
# ### Bu hücre, Kaggle input dizini salt okunur olduğu için bozuk dosyaları silmek yerine, sağlam görselleri yeni bir klasöre kopyalar. Sonuç olarak, bozuk dosyalar filtrelenmiş ve model eğitimi için hazır bir veri seti oluşturulur.

# %%
import os
import shutil
import random

random.seed(42)

split_base = "/kaggle/working/cats_and_dogs_split"
for folder in ["train", "val", "test"]:
    for label in ["Cat", "Dog"]:
        os.makedirs(os.path.join(split_base, folder, label), exist_ok=True)

for label in ["Cat", "Dog"]:
    files = os.listdir(os.path.join(clean_base, label))
    random.shuffle(files)
    n = len(files)
    train_end = int(0.7 * n)
    val_end = int(0.85 * n)

    for i, file in enumerate(files):
        src = os.path.join(clean_base, label, file)
        if i < train_end:
            dst = os.path.join(split_base, "train", label, file)
        elif i < val_end:
            dst = os.path.join(split_base, "val", label, file)
        else:
            dst = os.path.join(split_base, "test", label, file)
        shutil.copy(src, dst)

print("Train/Validation/Test ayrımı tamamlandı!")
# Out:
# Train/Validation/Test ayrımı tamamlandı!

# %% [markdown]
# ## Bu hücre, temizlenmiş kedi ve köpek resimlerini eğitim, doğrulama ve test setlerine böler. %70 eğitim (train)
#
# %15 doğrulama (val)
# %15 test (test)
# shutil.copy ile sağlam resimler ilgili alt klasörlere kopyalanır
# Sonuç olarak, model eğitimi için hazır bir veri seti yapısı elde edilir.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # 0=all, 1=info, 2=warning, 3=error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2025-09-25 23:46:36.956693: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1758843997.144541      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1758843997.199236      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ### Bu hücre, derin öğrenme modeli oluşturmak için gerekli kütüphaneleri yükler. TensorFlow uyarı mesajlarını gizler (sadece kritik hatalar görünür)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Train verisi için augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Validation ve test verisi için sadece rescale
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Dizinleri tanımla
train_dir = "/kaggle/working/cats_and_dogs_split/train"
val_dir = "/kaggle/working/cats_and_dogs_split/val"
test_dir = "/kaggle/working/cats_and_dogs_split/test"

# Data generatorları oluştur
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary'
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary'
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 17462 images belonging to 2 classes.
# Found 3741 images belonging to 2 classes.
# Found 3743 images belonging to 2 classes.

# %% [markdown]
# ## Bu hücre, modelin eğitimi için veri üreteçlerini (generators) hazırlar. Bu yapı ile model, veriyi memory’ye yüklemeden, batch batch eğitilebilir.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # binary classification için
])

model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1758844011.665039      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1758844011.665802      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 36992)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    18,940,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,034,177 (72.61 MB)
#  Trainable params: 19,034,177 (72.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Bu çıktı, modelin doğru şekilde oluşturulduğunu ve eğitime hazır olduğunu gösterir. Model Mimarisi (Sequential), Model Derleme ve Model Özeti kısımlarını içerir.

# %%
# Modeli eğit
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=val_generator,
    validation_steps=val_generator.samples // val_generator.batch_size,
    epochs=10  # Dilersen 15-20 yapabilirsin
)

# Accuracy grafiği
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss grafiği
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758844016.333626      81 service.cc:148] XLA service 0x79eb38005220 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1758844016.334391      81 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1758844016.334418      81 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1758844016.715766      81 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/545 ━━━━━━━━━━━━━━━━━━━━ 1:04:28 7s/step - accuracy: 0.5000 - loss: 0.7033
# I0000 00:00:1758844020.648188      81 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.5556 - loss: 0.7419
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 116s 200ms/step - accuracy: 0.5557 - loss: 0.7418 - val_accuracy: 0.6509 - val_loss: 0.6283
# Epoch 2/10
#   1/545 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - accuracy: 0.6875 - loss: 0.7424
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6875 - loss: 0.7424 - val_accuracy: 0.6754 - val_loss: 0.6137
# Epoch 3/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 100s 183ms/step - accuracy: 0.6572 - loss: 0.6243 - val_accuracy: 0.7344 - val_loss: 0.5362
# Epoch 4/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6875 - loss: 0.6348 - val_accuracy: 0.7303 - val_loss: 0.5399
# Epoch 5/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 99s 182ms/step - accuracy: 0.7025 - loss: 0.5690 - val_accuracy: 0.7767 - val_loss: 0.4752
# Epoch 6/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6875 - loss: 0.6135 - val_accuracy: 0.7756 - val_loss: 0.4768
# Epoch 7/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 100s 183ms/step - accuracy: 0.7317 - loss: 0.5346 - val_accuracy: 0.7880 - val_loss: 0.4624
# Epoch 8/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8438 - loss: 0.4114 - val_accuracy: 0.7799 - val_loss: 0.4717
# Epoch 9/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 101s 186ms/step - accuracy: 0.7513 - loss: 0.5118 - val_accuracy: 0.7355 - val_loss: 0.5414
# Epoch 10/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7500 - loss: 0.4940 - val_accuracy: 0.7443 - val_loss: 0.5326

# %% [markdown]
# ## Model Eğitimi ve Eğitim Grafikleri¶
# Model Fit:
#
# train_generator ve val_generator kullanılarak model 10 epoch boyunca eğitilir
# steps_per_epoch ve validation_steps batch sayısına göre hesaplanır
# Accuracy Grafiği:
#
# history.history['accuracy'] → eğitim doğruluğu
# history.history['val_accuracy'] → doğrulama doğruluğu
# Epoch ilerledikçe modelin performansı gözlemlenir
# Loss Grafiği:
#
# history.history['loss'] → eğitim kaybı
# history.history['val_loss'] → doğrulama kaybı
# Modelin öğrenme durumu ve overfitting kontrolü yapılabilir
# Bu görselleştirmeler ile modelin eğitim süreci detaylı olarak izlenebilir.

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Test seti üzerinde tahmin yap
y_pred = model.predict(test_generator)
y_pred_classes = np.where(y_pred > 0.5, 1, 0)

# Gerçek etiketler
y_true = test_generator.classes

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Cat','Dog'], yticklabels=['Cat','Dog'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(y_true, y_pred_classes, target_names=['Cat','Dog']))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step
#               precision    recall  f1-score   support
#
#          Cat       0.84      0.57      0.68      1872
#          Dog       0.67      0.89      0.77      1871
#
#     accuracy                           0.73      3743
#    macro avg       0.76      0.73      0.72      3743
# weighted avg       0.76      0.73      0.72      3743

# %% [markdown]
# ## Test Seti ile Model Değerlendirme
# Tahmin Yapma:
#
# model.predict(test_generator) ile test verisi üzerinde tahminler alınır
# y_pred_classes ile tahminler 0 veya 1 olarak binary sınıflara çevrilir
# Confusion Matrix (Karmaşıklık Matrisi):
#
# Modelin doğru ve yanlış tahminleri görselleştirilir
# sns.heatmap ile kolay okunabilir bir matris çizilir
# Classification Report:
#
# precision, recall, f1-score ve support değerleri hesaplanır
# Hangi sınıfta modelin performansının daha iyi olduğunu gösterir
# Bu adım modelin gerçek test verisi üzerindeki başarısını detaylı olarak analiz eder.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model

def get_img_array(img_path, size):
    # Görüntüyü oku ve boyutlandır
    img = tf.keras.utils.load_img(img_path, target_size=size)
    array = tf.keras.utils.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    array /= 255.0
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]
    
    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0,1,2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def display_gradcam(img_path, heatmap, alpha=0.4):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    heatmap_color = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    superimposed_img = cv2.addWeighted(img, 1-alpha, heatmap_color, alpha, 0)
    
    plt.figure(figsize=(6,6))
    plt.imshow(superimposed_img)
    plt.axis('off')
    plt.show()

# %% [markdown]
# # Grad-CAM Görselleştirmesi için Fonksiyonlar
# Görseli Hazırlama (get_img_array)
#
# Görseli okur, target_size ile boyutlandırır ve 0-1 arasında normalize eder
# Grad-CAM Isı Haritası Üretme (make_gradcam_heatmap)
#
# Son konvolüsyon katmanı üzerinden sınıf aktivasyonlarını hesaplar
# Grad-CAM tekniği ile hangi bölgelerin sınıf tahminine etkili olduğunu görselleştirmek için ısı haritası üretir
# Grad-CAM Görselleştirme (display_gradcam)
#
# Orijinal görsel ile ısı haritasını üst üste bindirir
# alpha parametresi ile ısı haritasının şeffaflığı ayarlanabilir
# Bu fonksiyonlar sayesinde modelin hangi bölgelere dikkat ederek tahmin yaptığını görselleştirebilirsin.

# %%
import os

# Test Cat ve Dog klasöründeki dosyaları listele
cat_test_files = os.listdir("/kaggle/working/cats_and_dogs_split/test/Cat")
dog_test_files = os.listdir("/kaggle/working/cats_and_dogs_split/test/Dog")

# Örnek olarak ilk Cat görselini seç
img_path = "/kaggle/working/cats_and_dogs_split/test/Cat/" + cat_test_files[0]

print("Grad-CAM uygulanacak görsel:", img_path)
# Out:
# Grad-CAM uygulanacak görsel: /kaggle/working/cats_and_dogs_split/test/Cat/7150.jpg

# %% [markdown]
# ## Grad-CAM için Örnek Görsel Seçimi
# Test Setindeki Görsellerin Listelenmesi:
#
# Cat ve Dog klasörlerindeki dosyalar os.listdir ile alınır
# Örnek Görsel Seçimi:
#
# İlk Cat görseli örnek olarak seçilir
# img_path değişkeni ile Grad-CAM uygulanacak görselin yolu belirlenir
# Bilgilendirme:
#
# print ile seçilen görselin yolu gösterilir

# %%
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model

# Görseli oku ve boyutlandır
def get_img_array(img_path, size=(150,150)):
    img = tf.keras.utils.load_img(img_path, target_size=size)
    array = tf.keras.utils.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    array /= 255.0
    return array

# Grad-CAM heatmap oluştur
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]

    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0,1,2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# Grad-CAM görselleştir
def display_gradcam(img_path, heatmap, alpha=0.4):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ## Grad-CAM ile Görsel Analizi
# Modelin tahminlerde hangi bölgelere dikkat ettiğini görselleştirmek için Grad-CAM yöntemi kullanılmıştır.

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Görseli array’e çevir
img_array = get_img_array(img_path, size=(150,150))


# Modelden tahmin al (bu aynı zamanda modelin çağrılmasını sağlar)
preds = model.predict(img_array)
print("Tahmin:", preds)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step
# Tahmin: [[0.15876675]]

# %% [markdown]
# ## Tek Görsel Tahmini
# Seçilen test görseli modelden geçirilmiş ve tahmin sonucu ekrana yazdırılmıştır.
#
# Çıktı: 0.09125093 → Model bu görselin Cat olma olasılığını %9.1 olarak tahmin etti.

# %%
import os

test_cat_dir = "/kaggle/working/cats_and_dogs_split/test/Cat"
test_imgs = os.listdir(test_cat_dir)
img_path = os.path.join(test_cat_dir, test_imgs[0])  # klasördeki ilk Cat görseli

# %% [markdown]
# ## Test veri klasöründeki bir kedi görselini alıyoruz.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 1️⃣ ImageDataGenerator ile veri hazırlama
train_dir = "/kaggle/working/cats_and_dogs_split/train"
test_dir = "/kaggle/working/cats_and_dogs_split/test"

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary'
)

# 2️⃣ Functional API ile model tanımlama
inputs = Input(shape=(150,150,3))
x = Conv2D(32, (3,3), activation='relu')(inputs)
x = MaxPooling2D((2,2))(x)
x = Conv2D(64, (3,3), activation='relu')(x)
x = MaxPooling2D((2,2))(x)
x = Conv2D(128, (3,3), activation='relu', name='last_conv')(x)
x = MaxPooling2D((2,2))(x)
x = Flatten()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
outputs = Dense(1, activation='sigmoid')(x)

model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 3️⃣ Modeli eğit
history = model.fit(
    train_generator,
    epochs=5,
    validation_data=test_generator
)
# Out:
# Found 17462 images belonging to 2 classes.
# Found 3743 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 546/546 ━━━━━━━━━━━━━━━━━━━━ 105s 186ms/step - accuracy: 0.5409 - loss: 0.7212 - val_accuracy: 0.6265 - val_loss: 0.6349
# Epoch 2/5
# 546/546 ━━━━━━━━━━━━━━━━━━━━ 99s 182ms/step - accuracy: 0.6346 - loss: 0.6437 - val_accuracy: 0.7067 - val_loss: 0.5663
# Epoch 3/5
# 546/546 ━━━━━━━━━━━━━━━━━━━━ 99s 182ms/step - accuracy: 0.6751 - loss: 0.5981 - val_accuracy: 0.7056 - val_loss: 0.5661
# Epoch 4/5
# 546/546 ━━━━━━━━━━━━━━━━━━━━ 100s 183ms/step - accuracy: 0.7155 - loss: 0.5543 - val_accuracy: 0.7280 - val_loss: 0.5293
# Epoch 5/5
# 546/546 ━━━━━━━━━━━━━━━━━━━━ 99s 182ms/step - accuracy: 0.7280 - loss: 0.5378 - val_accuracy: 0.7809 - val_loss: 0.4713

# %% [markdown]
# Cats vs Dogs Sınıflandırma Projesi
# - 1️ Veri Hazırlama
# ImageDataGenerator ile eğitim ve test verilerini hazırlıyoruz.
# Eğitim verisi için veri artırma (augmentation) uygulandı: döndürme, kaydırma, zoom, yatay çevirme vb.
# Test verisi sadece normalizasyon (rescale) uygulandı.
# - 2️ Model Tanımlama
# Functional API kullanarak basit bir Convolutional Neural Network (CNN) oluşturuldu.
# Katmanlar:
# 3 adet Conv2D + MaxPooling
# Flatten
# Dense katmanı (512 nöron, ReLU)
# Dropout (0.5)
# Çıkış katmanı: 1 nöron, sigmoid (binary sınıflama)
# - 3️ Model Eğitimi
# Model binary_crossentropy loss ve adam optimizer ile derlendi.
# 5 epoch boyunca eğitim ve doğrulama seti ile eğitildi.
# history değişkeni ile eğitim sürecinde loss ve accuracy değerleri takip edildi.

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# Test klasöründeki görsellerden birini al
test_cat_folder = "/kaggle/working/cats_and_dogs_split/test/Cat"
test_images = os.listdir(test_cat_folder)
img_path = os.path.join(test_cat_folder, test_images[0])  # ilk görseli al

# 1️⃣ Görseli yükleme ve diziye çevirme
def get_img_array(img_path, size=(150, 150)):
    img = image.load_img(img_path, target_size=size)
    array = image.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    return array

# 2️⃣ Grad-CAM hesaplama
def make_gradcam_heatmap(img_array, model, last_conv_layer_name="last_conv"):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, 0]

    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# 3️⃣ Grad-CAM görselleştirme
def display_gradcam(img_path, heatmap, alpha=0.4):
    img = image.load_img(img_path)
    img = image.img_to_array(img).astype(np.uint8)

    heatmap = tf.image.resize(heatmap[..., np.newaxis], (img.shape[0], img.shape[1]))
    heatmap = np.uint8(255 * heatmap)
    heatmap = np.repeat(heatmap, 3, axis=-1)

    superimposed_img = img * (1 - alpha) + heatmap * alpha
    superimposed_img = np.uint8(superimposed_img)

    plt.figure(figsize=(6,6))
    plt.imshow(superimposed_img)
    plt.axis("off")
    plt.show()

# 4️⃣ Çalıştır
img_array = get_img_array(img_path)
heatmap = make_gradcam_heatmap(img_array, model)
display_gradcam(img_path, heatmap)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: [['keras_tensor_11']]
# Received: inputs=Tensor(shape=(1, 150, 150, 3))
#   warnings.warn(msg)
# /tmp/ipykernel_19/3647933069.py:44: RuntimeWarning: invalid value encountered in cast
#   heatmap = np.uint8(255 * heatmap)

# %% [markdown]
# ## Tek Görsel için Grad-CAM Uygulaması¶
# -  Test Görselini Hazırlama
# Test klasöründen bir kedi görseli seçildi.
# get_img_array fonksiyonu ile görsel 150x150 boyutuna ölçeklendi ve array'e çevrildi.
# -  Grad-CAM Hesaplama
# make_gradcam_heatmap fonksiyonu:
# Modelin son Conv2D katmanının çıktısını ve tahminini alıyor.
# Grad-CAM algoritması ile görselin hangi bölgelerinin tahminde etkili olduğunu belirliyor.
# Çıktı olarak 0-1 aralığında bir heatmap üretiyor.
# -  Grad-CAM Görselleştirme
# display_gradcam fonksiyonu:
# Orijinal görsel ile heatmap’i birleştiriyor.
# Sonucu matplotlib ile ekranda gösteriyor.
# -  Çalıştırma
# Seçilen görsel array'e çevrilip Grad-CAM heatmap'i oluşturuldu ve görselleştirildi.

# %%
import os

test_cat_folder = "/kaggle/working/cats_and_dogs_split/test/Cat"
# Test klasöründeki ilk görseli seç
img_file = os.listdir(test_cat_folder)[0]
img_path = os.path.join(test_cat_folder, img_file)

# Sonra Grad-CAM kodunu kullanabiliriz
img_array = get_img_array(img_path)
heatmap = make_gradcam_heatmap(img_array, model)
display_gradcam(img_path, heatmap)
# Out:
# /tmp/ipykernel_19/3647933069.py:44: RuntimeWarning: invalid value encountered in cast
#   heatmap = np.uint8(255 * heatmap)

# %% [markdown]
# ## Tek Görsel Seçimi ve Grad-CAM Uygulama
# Test klasöründen ilk kedi görseli seçildi.
# get_img_array ile görsel array'e çevrildi.
# make_gradcam_heatmap ile heatmap hesaplandı.
# display_gradcam ile görsel üzerine heatmap uygulanıp gösterildi.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing import image

# Test klasörleri
test_folder = "/kaggle/working/cats_and_dogs_split/test"
output_folder = "/kaggle/working/gradcam_results"

# Klasörleri oluştur
for category in ["Cat", "Dog"]:
    os.makedirs(os.path.join(output_folder, category), exist_ok=True)

def get_img_array(img_path, target_size=(150,150)):
    img = image.load_img(img_path, target_size=target_size)
    array = image.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    array = array / 255.0
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name="last_conv"):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, 0]
    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = tf.reduce_mean(tf.multiply(conv_outputs, pooled_grads), axis=-1)
    heatmap = np.maximum(heatmap, 0)
    heatmap /= tf.reduce_max(heatmap) if tf.reduce_max(heatmap) != 0 else 1
    heatmap = np.uint8(255 * heatmap)
    return heatmap

def display_gradcam(img_path, heatmap, alpha=0.4):
    img = image.load_img(img_path)
    img = image.img_to_array(img).astype(np.uint8)
    heatmap = np.expand_dims(heatmap, axis=-1)
    heatmap = np.repeat(heatmap, 3, axis=-1)
    superimposed_img = heatmap * alpha + img
    superimposed_img = np.clip(superimposed_img, 0, 255).astype(np.uint8)
    return superimposed_img

# Burada model değişkenini doğrudan kullanıyoruz, tekrar load_model yok
for category in ["Cat", "Dog"]:
    category_folder = os.path.join(test_folder, category)
    for img_file in os.listdir(category_folder):
        img_path = os.path.join(category_folder, img_file)
        try:
            img_array = get_img_array(img_path)
            heatmap = make_gradcam_heatmap(img_array, model)
            superimposed_img = display_gradcam(img_path, heatmap)
            
            save_path = os.path.join(output_folder, category, img_file)
            plt.imsave(save_path, superimposed_img)
        except Exception as e:
            print(f"Atlandı: {img_path} ({e})")
            continue

print("Tüm test görselleri için Grad-CAM oluşturuldu ve kaydedildi.")
# Out:
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7150.jpg (operands could not be broadcast together with shapes (34,34,3) (360,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5700.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5038.jpg (operands could not be broadcast together with shapes (34,34,3) (233,311,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3029.jpg (operands could not be broadcast together with shapes (34,34,3) (268,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1809.jpg (operands could not be broadcast together with shapes (34,34,3) (262,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10883.jpg (operands could not be broadcast together with shapes (34,34,3) (314,426,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9762.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10520.jpg (operands could not be broadcast together with shapes (34,34,3) (200,185,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3883.jpg (operands could not be broadcast together with shapes (34,34,3) (336,448,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6071.jpg (operands could not be broadcast together with shapes (34,34,3) (321,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1653.jpg (operands could not be broadcast together with shapes (34,34,3) (400,235,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11821.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10615.jpg (operands could not be broadcast together with shapes (34,34,3) (380,468,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2341.jpg (operands could not be broadcast together with shapes (34,34,3) (417,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3679.jpg (operands could not be broadcast together with shapes (34,34,3) (460,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/252.jpg (operands could not be broadcast together with shapes (34,34,3) (113,150,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11866.jpg (operands could not be broadcast together with shapes (34,34,3) (189,322,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/587.jpg (operands could not be broadcast together with shapes (34,34,3) (240,255,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5323.jpg (operands could not be broadcast together with shapes (34,34,3) (349,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2267.jpg (operands could not be broadcast together with shapes (34,34,3) (344,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2577.jpg (operands could not be broadcast together with shapes (34,34,3) (200,141,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1728.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8429.jpg (operands could not be broadcast together with shapes (34,34,3) (500,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3119.jpg (operands could not be broadcast together with shapes (34,34,3) (164,216,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7773.jpg (operands could not be broadcast together with shapes (34,34,3) (480,494,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/616.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11993.jpg (operands could not be broadcast together with shapes (34,34,3) (473,351,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1008.jpg (operands could not be broadcast together with shapes (34,34,3) (368,329,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8879.jpg (operands could not be broadcast together with shapes (34,34,3) (442,451,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2220.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3559.jpg (operands could not be broadcast together with shapes (34,34,3) (402,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6838.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3036.jpg (operands could not be broadcast together with shapes (34,34,3) (441,428,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11364.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5113.jpg (operands could not be broadcast together with shapes (34,34,3) (448,338,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11102.jpg (operands could not be broadcast together with shapes (34,34,3) (500,440,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7017.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10993.jpg (operands could not be broadcast together with shapes (34,34,3) (332,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/356.jpg (operands could not be broadcast together with shapes (34,34,3) (405,450,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3648.jpg (operands could not be broadcast together with shapes (34,34,3) (416,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2051.jpg (operands could not be broadcast together with shapes (34,34,3) (500,395,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8244.jpg (operands could not be broadcast together with shapes (34,34,3) (500,379,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/857.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4562.jpg (operands could not be broadcast together with shapes (34,34,3) (336,448,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1523.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11557.jpg (operands could not be broadcast together with shapes (34,34,3) (151,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8349.jpg (operands could not be broadcast together with shapes (34,34,3) (374,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1668.jpg (operands could not be broadcast together with shapes (34,34,3) (292,448,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/754.jpg (operands could not be broadcast together with shapes (34,34,3) (175,192,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3048.jpg (operands could not be broadcast together with shapes (34,34,3) (335,430,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2989.jpg (operands could not be broadcast together with shapes (34,34,3) (387,440,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/697.jpg (operands could not be broadcast together with shapes (34,34,3) (332,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9345.jpg (operands could not be broadcast together with shapes (34,34,3) (476,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3952.jpg (operands could not be broadcast together with shapes (34,34,3) (225,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4707.jpg (operands could not be broadcast together with shapes (34,34,3) (480,407,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5373.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10508.jpg (operands could not be broadcast together with shapes (34,34,3) (379,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/247.jpg (operands could not be broadcast together with shapes (34,34,3) (427,385,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8598.jpg (operands could not be broadcast together with shapes (34,34,3) (500,370,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7929.jpg (operands could not be broadcast together with shapes (34,34,3) (500,437,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7793.jpg (operands could not be broadcast together with shapes (34,34,3) (349,318,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8699.jpg (operands could not be broadcast together with shapes (34,34,3) (500,277,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6257.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/879.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11051.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3486.jpg (operands could not be broadcast together with shapes (34,34,3) (331,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8731.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8145.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8229.jpg (operands could not be broadcast together with shapes (34,34,3) (366,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/470.jpg (operands could not be broadcast together with shapes (34,34,3) (400,266,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11246.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6141.jpg (operands could not be broadcast together with shapes (34,34,3) (500,371,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7171.jpg (operands could not be broadcast together with shapes (34,34,3) (184,108,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4709.jpg (operands could not be broadcast together with shapes (34,34,3) (378,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2017.jpg (operands could not be broadcast together with shapes (34,34,3) (300,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2636.jpg (operands could not be broadcast together with shapes (34,34,3) (400,339,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3694.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2866.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10164.jpg (operands could not be broadcast together with shapes (34,34,3) (271,240,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3094.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8651.jpg (operands could not be broadcast together with shapes (34,34,3) (423,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8320.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11445.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/912.jpg (operands could not be broadcast together with shapes (34,34,3) (378,316,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4752.jpg (operands could not be broadcast together with shapes (34,34,3) (500,387,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5675.jpg (operands could not be broadcast together with shapes (34,34,3) (500,430,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3503.jpg (operands could not be broadcast together with shapes (34,34,3) (180,240,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10714.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5707.jpg (operands could not be broadcast together with shapes (34,34,3) (500,458,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7373.jpg (operands could not be broadcast together with shapes (34,34,3) (500,433,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5903.jpg (operands could not be broadcast together with shapes (34,34,3) (313,450,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6949.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11687.jpg (operands could not be broadcast together with shapes (34,34,3) (279,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8258.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9807.jpg (operands could not be broadcast together with shapes (34,34,3) (336,368,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1397.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10673.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6269.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9186.jpg (operands could not be broadcast together with shapes (34,34,3) (450,474,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12382.jpg (operands could not be broadcast together with shapes (34,34,3) (357,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10191.jpg (operands could not be broadcast together with shapes (34,34,3) (312,468,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3239.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9981.jpg (operands could not be broadcast together with shapes (34,34,3) (500,373,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3842.jpg (operands could not be broadcast together with shapes (34,34,3) (300,202,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5868.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9033.jpg (operands could not be broadcast together with shapes (34,34,3) (175,117,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/468.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7158.jpg (operands could not be broadcast together with shapes (34,34,3) (409,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/750.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11455.jpg (operands could not be broadcast together with shapes (34,34,3) (254,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7803.jpg (operands could not be broadcast together with shapes (34,34,3) (483,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9323.jpg (operands could not be broadcast together with shapes (34,34,3) (500,433,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5740.jpg (operands could not be broadcast together with shapes (34,34,3) (150,240,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9017.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10535.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3824.jpg (operands could not be broadcast together with shapes (34,34,3) (336,448,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8137.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3768.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5797.jpg (operands could not be broadcast together with shapes (34,34,3) (273,313,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3268.jpg (operands could not be broadcast together with shapes (34,34,3) (398,426,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10973.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11722.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12260.jpg (operands could not be broadcast together with shapes (34,34,3) (225,190,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4609.jpg (operands could not be broadcast together with shapes (34,34,3) (331,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1928.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3484.jpg (operands could not be broadcast together with shapes (34,34,3) (351,420,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/276.jpg (operands could not be broadcast together with shapes (34,34,3) (404,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6776.jpg (operands could not be broadcast together with shapes (34,34,3) (245,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4545.jpg (operands could not be broadcast together with shapes (34,34,3) (340,336,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6424.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/836.jpg (operands could not be broadcast together with shapes (34,34,3) (447,440,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3692.jpg (operands could not be broadcast together with shapes (34,34,3) (353,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8550.jpg (operands could not be broadcast together with shapes (34,34,3) (434,422,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11512.jpg (operands could not be broadcast together with shapes (34,34,3) (500,185,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10273.jpg (operands could not be broadcast together with shapes (34,34,3) (326,351,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1720.jpg (operands could not be broadcast together with shapes (34,34,3) (500,473,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9837.jpg (operands could not be broadcast together with shapes (34,34,3) (124,121,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3641.jpg (operands could not be broadcast together with shapes (34,34,3) (60,96,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10369.jpg (operands could not be broadcast together with shapes (34,34,3) (185,178,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12233.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2813.jpg (operands could not be broadcast together with shapes (34,34,3) (394,499,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11472.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/714.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1250.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11016.jpg (operands could not be broadcast together with shapes (34,34,3) (500,460,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5114.jpg (operands could not be broadcast together with shapes (34,34,3) (224,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10250.jpg (operands could not be broadcast together with shapes (34,34,3) (144,106,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5601.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1223.jpg (operands could not be broadcast together with shapes (34,34,3) (500,428,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6697.jpg (operands could not be broadcast together with shapes (34,34,3) (374,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/873.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1923.jpg (operands could not be broadcast together with shapes (34,34,3) (500,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1031.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7970.jpg (operands could not be broadcast together with shapes (34,34,3) (458,371,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10932.jpg (operands could not be broadcast together with shapes (34,34,3) (360,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10707.jpg (operands could not be broadcast together with shapes (34,34,3) (374,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6789.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11734.jpg (operands could not be broadcast together with shapes (34,34,3) (398,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/40.jpg (operands could not be broadcast together with shapes (34,34,3) (383,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6603.jpg (operands could not be broadcast together with shapes (34,34,3) (366,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1861.jpg (operands could not be broadcast together with shapes (34,34,3) (263,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6824.jpg (operands could not be broadcast together with shapes (34,34,3) (262,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1546.jpg (operands could not be broadcast together with shapes (34,34,3) (431,285,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10951.jpg (operands could not be broadcast together with shapes (34,34,3) (388,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8740.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1765.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5361.jpg (operands could not be broadcast together with shapes (34,34,3) (262,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2205.jpg (operands could not be broadcast together with shapes (34,34,3) (302,264,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/227.jpg (operands could not be broadcast together with shapes (34,34,3) (336,448,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5237.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10516.jpg (operands could not be broadcast together with shapes (34,34,3) (500,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6695.jpg (operands could not be broadcast together with shapes (34,34,3) (256,298,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11379.jpg (operands could not be broadcast together with shapes (34,34,3) (374,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5490.jpg (operands could not be broadcast together with shapes (34,34,3) (232,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10576.jpg (operands could not be broadcast together with shapes (34,34,3) (398,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2402.jpg (operands could not be broadcast together with shapes (34,34,3) (336,481,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10166.jpg (operands could not be broadcast together with shapes (34,34,3) (262,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/614.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5247.jpg (operands could not be broadcast together with shapes (34,34,3) (336,391,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/447.jpg (operands could not be broadcast together with shapes (34,34,3) (500,489,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4070.jpg (operands could not be broadcast together with shapes (34,34,3) (397,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11775.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2436.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8700.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3021.jpg (operands could not be broadcast together with shapes (34,34,3) (481,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7314.jpg (operands could not be broadcast together with shapes (34,34,3) (70,60,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2276.jpg (operands could not be broadcast together with shapes (34,34,3) (250,199,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8309.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12315.jpg (operands could not be broadcast together with shapes (34,34,3) (158,263,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9740.jpg (operands could not be broadcast together with shapes (34,34,3) (480,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8891.jpg (operands could not be broadcast together with shapes (34,34,3) (402,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6538.jpg (operands could not be broadcast together with shapes (34,34,3) (500,323,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10840.jpg (operands could not be broadcast together with shapes (34,34,3) (499,356,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4991.jpg (operands could not be broadcast together with shapes (34,34,3) (498,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1492.jpg (operands could not be broadcast together with shapes (34,34,3) (350,383,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8224.jpg (operands could not be broadcast together with shapes (34,34,3) (339,450,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1732.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9400.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5684.jpg (operands could not be broadcast together with shapes (34,34,3) (223,288,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12336.jpg (operands could not be broadcast together with shapes (34,34,3) (500,359,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8893.jpg (operands could not be broadcast together with shapes (34,34,3) (350,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2840.jpg (operands could not be broadcast together with shapes (34,34,3) (500,403,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5158.jpg (operands could not be broadcast together with shapes (34,34,3) (345,303,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/791.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11192.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8443.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3640.jpg (operands could not be broadcast together with shapes (34,34,3) (249,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7513.jpg (operands could not be broadcast together with shapes (34,34,3) (300,257,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2459.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7991.jpg (operands could not be broadcast together with shapes (34,34,3) (445,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2795.jpg (operands could not be broadcast together with shapes (34,34,3) (421,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5963.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2864.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3758.jpg (operands could not be broadcast together with shapes (34,34,3) (112,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5349.jpg (operands could not be broadcast together with shapes (34,34,3) (427,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2196.jpg (operands could not be broadcast together with shapes (34,34,3) (500,390,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10219.jpg (operands could not be broadcast together with shapes (34,34,3) (300,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8946.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/92.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9482.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11339.jpg (operands could not be broadcast together with shapes (34,34,3) (336,383,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8725.jpg (operands could not be broadcast together with shapes (34,34,3) (500,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3504.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9780.jpg (operands could not be broadcast together with shapes (34,34,3) (499,425,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12383.jpg (operands could not be broadcast together with shapes (34,34,3) (312,410,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10075.jpg (operands could not be broadcast together with shapes (34,34,3) (216,288,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11194.jpg (operands could not be broadcast together with shapes (34,34,3) (500,394,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/797.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10091.jpg (operands could not be broadcast together with shapes (34,34,3) (182,141,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11613.jpg (operands could not be broadcast together with shapes (34,34,3) (150,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1110.jpg (operands could not be broadcast together with shapes (34,34,3) (161,135,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2376.jpg (operands could not be broadcast together with shapes (34,34,3) (338,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8984.jpg (operands could not be broadcast together with shapes (34,34,3) (500,442,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5856.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5682.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7290.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1944.jpg (operands could not be broadcast together with shapes (34,34,3) (500,374,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9389.jpg (operands could not be broadcast together with shapes (34,34,3) (347,490,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10694.jpg (operands could not be broadcast together with shapes (34,34,3) (423,356,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7917.jpg (operands could not be broadcast together with shapes (34,34,3) (500,290,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2537.jpg (operands could not be broadcast together with shapes (34,34,3) (368,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5845.jpg (operands could not be broadcast together with shapes (34,34,3) (374,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4553.jpg (operands could not be broadcast together with shapes (34,34,3) (270,360,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2454.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/984.jpg (operands could not be broadcast together with shapes (34,34,3) (334,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8432.jpg (operands could not be broadcast together with shapes (34,34,3) (187,250,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2378.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10558.jpg (operands could not be broadcast together with shapes (34,34,3) (299,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4623.jpg (operands could not be broadcast together with shapes (34,34,3) (455,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8747.jpg (operands could not be broadcast together with shapes (34,34,3) (386,432,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7204.jpg (operands could not be broadcast together with shapes (34,34,3) (400,284,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6767.jpg (operands could not be broadcast together with shapes (34,34,3) (500,433,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1071.jpg (operands could not be broadcast together with shapes (34,34,3) (400,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7307.jpg (operands could not be broadcast together with shapes (34,34,3) (500,303,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2680.jpg (operands could not be broadcast together with shapes (34,34,3) (391,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5192.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12220.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8656.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6572.jpg (operands could not be broadcast together with shapes (34,34,3) (478,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10672.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6340.jpg (operands could not be broadcast together with shapes (34,34,3) (500,357,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5025.jpg (operands could not be broadcast together with shapes (34,34,3) (230,163,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1056.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1925.jpg (operands could not be broadcast together with shapes (34,34,3) (303,476,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/255.jpg (operands could not be broadcast together with shapes (34,34,3) (500,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11265.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4093.jpg (operands could not be broadcast together with shapes (34,34,3) (359,336,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6166.jpg (operands could not be broadcast together with shapes (34,34,3) (348,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8502.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9380.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11088.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2286.jpg (operands could not be broadcast together with shapes (34,34,3) (384,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2659.jpg (operands could not be broadcast together with shapes (34,34,3) (375,307,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/123.jpg (operands could not be broadcast together with shapes (34,34,3) (273,345,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11508.jpg (operands could not be broadcast together with shapes (34,34,3) (290,387,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/862.jpg (operands could not be broadcast together with shapes (34,34,3) (96,140,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1240.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8416.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12433.jpg (operands could not be broadcast together with shapes (34,34,3) (450,416,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4783.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/770.jpg (operands could not be broadcast together with shapes (34,34,3) (270,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10545.jpg (operands could not be broadcast together with shapes (34,34,3) (500,438,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9690.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7112.jpg (operands could not be broadcast together with shapes (34,34,3) (486,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4415.jpg (operands could not be broadcast together with shapes (34,34,3) (338,450,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5251.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4417.jpg (operands could not be broadcast together with shapes (34,34,3) (500,374,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6500.jpg (operands could not be broadcast together with shapes (34,34,3) (500,498,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1697.jpg (operands could not be broadcast together with shapes (34,34,3) (197,266,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/434.jpg (operands could not be broadcast together with shapes (34,34,3) (450,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5330.jpg (operands could not be broadcast together with shapes (34,34,3) (412,488,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4075.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3291.jpg (operands could not be broadcast together with shapes (34,34,3) (493,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5635.jpg (operands could not be broadcast together with shapes (34,34,3) (500,394,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/11203.jpg (operands could not be broadcast together with shapes (34,34,3) (315,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4212.jpg (operands could not be broadcast together with shapes (34,34,3) (500,396,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1014.jpg (operands could not be broadcast together with shapes (34,34,3) (336,344,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/12493.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4104.jpg (operands could not be broadcast together with shapes (34,34,3) (363,460,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1819.jpg (operands could not be broadcast together with shapes (34,34,3) (500,499,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4303.jpg (operands could not be broadcast together with shapes (34,34,3) (450,431,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5381.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10534.jpg (operands could not be broadcast together with shapes (34,34,3) (415,467,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8788.jpg (operands could not be broadcast together with shapes (34,34,3) (405,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9219.jpg (operands could not be broadcast together with shapes (34,34,3) (150,150,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/186.jpg (operands could not be broadcast together with shapes (34,34,3) (231,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3980.jpg (operands could not be broadcast together with shapes (34,34,3) (96,84,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1361.jpg (operands could not be broadcast together with shapes (34,34,3) (266,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3007.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/135.jpg (operands could not be broadcast together with shapes (34,34,3) (458,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8911.jpg (operands could not be broadcast together with shapes (34,34,3) (355,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9515.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8577.jpg (operands could not be broadcast together with shapes (34,34,3) (259,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/2714.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1636.jpg (operands could not be broadcast together with shapes (34,34,3) (416,368,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10999.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7053.jpg (operands could not be broadcast together with shapes (34,34,3) (338,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9561.jpg (operands could not be broadcast together with shapes (34,34,3) (500,424,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/7708.jpg (operands could not be broadcast together with shapes (34,34,3) (412,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/6474.jpg (operands could not be broadcast together with shapes (34,34,3) (489,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10243.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9965.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9466.jpg (operands could not be broadcast together with shapes (34,34,3) (410,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10347.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/264.jpg (operands could not be broadcast together with shapes (34,34,3) (292,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10302.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8161.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1987.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10023.jpg (operands could not be broadcast together with shapes (34,34,3) (336,350,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3546.jpg (operands could not be broadcast together with shapes (34,34,3) (374,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/8625.jpg (operands could not be broadcast together with shapes (34,34,3) (314,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10636.jpg (operands could not be broadcast together with shapes (34,34,3) (150,193,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3855.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10260.jpg (operands could not be broadcast together with shapes (34,34,3) (500,281,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/9988.jpg (operands could not be broadcast together with shapes (34,34,3) (362,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/1535.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/5953.jpg (operands could not be broadcast together with shapes (34,34,3) (500,359,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/4821.jpg (operands could not be broadcast together with shapes (34,34,3) (40,60,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/3801.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Cat/10858.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# ...
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2787.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5588.jpg (operands could not be broadcast together with shapes (34,34,3) (500,323,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7918.jpg (operands could not be broadcast together with shapes (34,34,3) (256,256,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2486.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3031.jpg (operands could not be broadcast together with shapes (34,34,3) (500,374,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/626.jpg (operands could not be broadcast together with shapes (34,34,3) (500,333,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11180.jpg (operands could not be broadcast together with shapes (34,34,3) (304,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11487.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/187.jpg (operands could not be broadcast together with shapes (34,34,3) (301,315,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/840.jpg (operands could not be broadcast together with shapes (34,34,3) (500,428,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4350.jpg (operands could not be broadcast together with shapes (34,34,3) (376,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1452.jpg (operands could not be broadcast together with shapes (34,34,3) (488,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2018.jpg (operands could not be broadcast together with shapes (34,34,3) (135,180,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7399.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10817.jpg (operands could not be broadcast together with shapes (34,34,3) (369,432,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6898.jpg (operands could not be broadcast together with shapes (34,34,3) (500,387,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4727.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9096.jpg (operands could not be broadcast together with shapes (34,34,3) (500,337,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5286.jpg (operands could not be broadcast together with shapes (34,34,3) (412,479,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3219.jpg (operands could not be broadcast together with shapes (34,34,3) (287,209,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9359.jpg (operands could not be broadcast together with shapes (34,34,3) (295,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4130.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11811.jpg (operands could not be broadcast together with shapes (34,34,3) (280,288,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6305.jpg (operands could not be broadcast together with shapes (34,34,3) (170,135,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2557.jpg (operands could not be broadcast together with shapes (34,34,3) (275,292,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6097.jpg (operands could not be broadcast together with shapes (34,34,3) (297,249,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6582.jpg (operands could not be broadcast together with shapes (34,34,3) (500,484,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3896.jpg (operands could not be broadcast together with shapes (34,34,3) (372,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8627.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9972.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3209.jpg (operands could not be broadcast together with shapes (34,34,3) (200,181,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6183.jpg (operands could not be broadcast together with shapes (34,34,3) (500,395,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11469.jpg (operands could not be broadcast together with shapes (34,34,3) (145,190,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8787.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11649.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5973.jpg (operands could not be broadcast together with shapes (34,34,3) (305,450,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1337.jpg (operands could not be broadcast together with shapes (34,34,3) (500,392,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6637.jpg (operands could not be broadcast together with shapes (34,34,3) (135,141,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5476.jpg (operands could not be broadcast together with shapes (34,34,3) (300,185,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2100.jpg (operands could not be broadcast together with shapes (34,34,3) (334,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11960.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/12418.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3327.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9020.jpg (operands could not be broadcast together with shapes (34,34,3) (414,405,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5402.jpg (operands could not be broadcast together with shapes (34,34,3) (166,160,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6086.jpg (operands could not be broadcast together with shapes (34,34,3) (286,179,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11887.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5130.jpg (operands could not be broadcast together with shapes (34,34,3) (500,332,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6418.jpg (operands could not be broadcast together with shapes (34,34,3) (453,422,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8337.jpg (operands could not be broadcast together with shapes (34,34,3) (409,307,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4987.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5833.jpg (operands could not be broadcast together with shapes (34,34,3) (500,462,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7605.jpg (operands could not be broadcast together with shapes (34,34,3) (325,325,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7933.jpg (operands could not be broadcast together with shapes (34,34,3) (381,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/126.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3040.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1587.jpg (operands could not be broadcast together with shapes (34,34,3) (500,357,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/12339.jpg (operands could not be broadcast together with shapes (34,34,3) (500,371,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/12006.jpg (operands could not be broadcast together with shapes (34,34,3) (300,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9877.jpg (operands could not be broadcast together with shapes (34,34,3) (350,216,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11359.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8155.jpg (operands could not be broadcast together with shapes (34,34,3) (500,490,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9563.jpg (operands could not be broadcast together with shapes (34,34,3) (177,181,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5597.jpg (operands could not be broadcast together with shapes (34,34,3) (500,357,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4543.jpg (operands could not be broadcast together with shapes (34,34,3) (200,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4361.jpg (operands could not be broadcast together with shapes (34,34,3) (225,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/768.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8720.jpg (operands could not be broadcast together with shapes (34,34,3) (240,180,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3863.jpg (operands could not be broadcast together with shapes (34,34,3) (500,231,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10098.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1937.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/3382.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/66.jpg (operands could not be broadcast together with shapes (34,34,3) (397,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8240.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8578.jpg (operands could not be broadcast together with shapes (34,34,3) (418,464,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4323.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2497.jpg (operands could not be broadcast together with shapes (34,34,3) (500,405,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5366.jpg (operands could not be broadcast together with shapes (34,34,3) (325,355,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1911.jpg (operands could not be broadcast together with shapes (34,34,3) (174,187,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5611.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4992.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4815.jpg (operands could not be broadcast together with shapes (34,34,3) (240,274,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/12143.jpg (operands could not be broadcast together with shapes (34,34,3) (378,189,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8536.jpg (operands could not be broadcast together with shapes (34,34,3) (360,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4917.jpg (operands could not be broadcast together with shapes (34,34,3) (300,400,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/786.jpg (operands could not be broadcast together with shapes (34,34,3) (400,300,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9891.jpg (operands could not be broadcast together with shapes (34,34,3) (402,480,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9950.jpg (operands could not be broadcast together with shapes (34,34,3) (489,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/9336.jpg (operands could not be broadcast together with shapes (34,34,3) (152,205,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8760.jpg (operands could not be broadcast together with shapes (34,34,3) (350,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10435.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1894.jpg (operands could not be broadcast together with shapes (34,34,3) (159,199,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2539.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4699.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/6972.jpg (operands could not be broadcast together with shapes (34,34,3) (213,200,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8642.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1704.jpg (operands could not be broadcast together with shapes (34,34,3) (365,250,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10058.jpg (operands could not be broadcast together with shapes (34,34,3) (413,440,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11700.jpg (operands could not be broadcast together with shapes (34,34,3) (465,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/11304.jpg (operands could not be broadcast together with shapes (34,34,3) (139,186,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5358.jpg (operands could not be broadcast together with shapes (34,34,3) (447,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10869.jpg (operands could not be broadcast together with shapes (34,34,3) (421,435,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/12400.jpg (operands could not be broadcast together with shapes (34,34,3) (383,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/1951.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/7791.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/8310.jpg (operands could not be broadcast together with shapes (34,34,3) (480,360,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/4961.jpg (operands could not be broadcast together with shapes (34,34,3) (352,337,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/5043.jpg (operands could not be broadcast together with shapes (34,34,3) (500,278,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/10729.jpg (operands could not be broadcast together with shapes (34,34,3) (94,100,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/2942.jpg (operands could not be broadcast together with shapes (34,34,3) (325,500,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/12439.jpg (operands could not be broadcast together with shapes (34,34,3) (500,420,3) )
# Atlandı: /kaggle/working/cats_and_dogs_split/test/Dog/12088.jpg (operands could not be broadcast together with shapes (34,34,3) (354,400,3) )
# Tüm test görselleri için Grad-CAM oluşturuldu ve kaydedildi.

# %% [markdown]
# ## Tüm Test Görselleri için Grad-CAM Oluşturma ve Kaydetme
# Test klasöründeki "Cat" ve "Dog" kategorilerindeki tüm görseller için Grad-CAM hesaplandı.
# get_img_array ile görseller array'e dönüştürüldü.
# make_gradcam_heatmap ile heatmap oluşturuldu.
# display_gradcam ile heatmap görselin üzerine uygulandı.
# Sonuçlar gradcam_results klasörüne kaydedildi.
# Hatalı veya bozuk görseller atlandı.

# %%
import matplotlib.pyplot as plt

# Eğitim & Doğrulama Accuracy grafiği
plt.figure(figsize=(8,6))
plt.plot(history.history['accuracy'], label='Eğitim Accuracy')
plt.plot(history.history['val_accuracy'], label='Doğrulama Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Eğitim & Doğrulama Loss grafiği
plt.figure(figsize=(8,6))
plt.plot(history.history['loss'], label='Eğitim Loss')
plt.plot(history.history['val_loss'], label='Doğrulama Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Modelin Eğitim Performans Grafikleri
# Accuracy Grafiği: Eğitim ve doğrulama accuracy değerlerinin epochlara göre değişimi.
# Loss Grafiği: Eğitim ve doğrulama kayıp (loss) değerlerinin epochlara göre değişimi.
# Bu grafikler modelin öğrenme sürecini görselleştirir ve overfitting veya underfitting durumlarını gözlemlemeye yardımcı olur.

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Test verisini yeniden yükle (ImageDataGenerator ile)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    "/kaggle/working/cats_and_dogs_split/test",
    target_size=(150,150),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)

# Modeli test setinde değerlendir
loss, acc = model.evaluate(test_generator, verbose=1)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {acc:.4f}")

# Tahminler
y_pred = model.predict(test_generator)
y_pred_classes = (y_pred > 0.5).astype("int32")
y_true = test_generator.classes

# Karışıklık matrisi
cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel("Tahmin")
plt.ylabel("Gerçek")
plt.title("Karışıklık Matrisi")
plt.show()

# Sınıflandırma raporu
print("\nSınıflandırma Raporu:\n")
print(classification_report(y_true, y_pred_classes, target_names=test_generator.class_indices.keys()))
# Out:
# Found 3743 images belonging to 2 classes.
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.7577 - loss: 0.5104
# Test Loss: 0.4713
# Test Accuracy: 0.7809
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step
# Sınıflandırma Raporu:
#
#               precision    recall  f1-score   support
#
#          Cat       0.79      0.76      0.78      1872
#          Dog       0.77      0.80      0.79      1871
#
#     accuracy                           0.78      3743
#    macro avg       0.78      0.78      0.78      3743
# weighted avg       0.78      0.78      0.78      3743

# %% [markdown]
# ### Model Değerlendirme: Test Verisi¶
# Test Loss ve Accuracy: Modelin test setindeki performansını özetler.
# Karışıklık Matrisi (Confusion Matrix): Modelin hangi sınıfları doğru veya yanlış tahmin ettiğini görselleştirir.
# Sınıflandırma Raporu (Classification Report): Precision, recall ve F1-score değerleri ile sınıf bazlı performansı özetler.
# Bu adım modelin gerçek veri üzerindeki doğruluğunu ve sınıflara göre başarısını incelemeye yarar.
