# %%
import os

base_path = "/kaggle/input"
for root, dirs, files in os.walk(base_path):
    print(root, len(files))
# Out:
# /kaggle/input 0
# /kaggle/input/microsoft-catsvsdogs-dataset 2
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages 0
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog 12501
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat 12501

# %% [markdown]
# ## Veri Klasör Yapısını Görüntüleme
#
# Bu kod, `/kaggle/input` klasörü altındaki tüm dizinleri ve her dizindeki dosya sayısını listeler.
# Amaç, veri setinin klasör yapısını ve içindeki dosya sayısını hızlıca kontrol etmektir.

# %%
import os

base_path = "/kaggle/input"
for root, dirs, files in os.walk(base_path):
    print(root, "->", len(files), "dosya")
# Out:
# /kaggle/input -> 0 dosya
# /kaggle/input/microsoft-catsvsdogs-dataset -> 2 dosya
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages -> 0 dosya
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog -> 12501 dosya
# /kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat -> 12501 dosya

# %% [markdown]
# ## Veri Klasör Yapısını Kontrol Etme
#
# Bu kod, `/kaggle/input` klasörü altındaki tüm dizinleri ve her dizinde kaç dosya olduğunu listeler.
# Amaç, veri setinin doğru şekilde yüklendiğini ve dosya sayısını kontrol etmektir.
#
# ```python
# import os
#
# base_path = "/kaggle/input"
# for root, dirs, files in os.walk(base_path):
#     print(root, "->", len(files), "dosya")

# %%
import os, cv2

cat_dir = "/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat"
dog_dir = "/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog"

def clean_images(folder):
    bad_files = []
    for file in os.listdir(folder):
        path = os.path.join(folder, file)
        try:
            img = cv2.imread(path)
            if img is None:
                bad_files.append(path)
        except:
            bad_files.append(path)
    return bad_files

bad_cats = clean_images(cat_dir)
bad_dogs = clean_images(dog_dir)

print("Bozuk kedi resimleri:", bad_cats)
print("Bozuk köpek resimleri:", bad_dogs)
# Out:
# Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# Warning: unknown JFIF revision number 0.00
# Corrupt JPEG data: 254 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1403 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 2230 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# Bozuk kedi resimleri: ['/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/4833.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/850.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/8470.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/11210.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/660.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/140.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/10820.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/10501.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/9171.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/9778.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/2663.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/11935.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/10125.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/11874.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/936.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/Thumbs.db', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/5553.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/7978.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/3491.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/3300.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/666.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/7968.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/11565.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/10404.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat/9565.jpg']
# Bozuk köpek resimleri: ['/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/6059.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11849.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/3288.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/6238.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/2688.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7112.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/8730.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11702.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7133.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11853.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7969.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7459.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/10747.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/6718.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/2877.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/3136.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11675.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/4367.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/Thumbs.db', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/5604.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/9188.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/3588.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/11410.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/1308.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/10158.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/2384.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/1866.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/7369.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/10797.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/10401.jpg', '/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog/5736.jpg']

# %% [markdown]
# Bu hücre, veri setindeki bozuk veya açılamayan resimleri tespit eder. Sonuç olarak, bozuk resimler ekrana yazdırılır ve sonraki adımlarda bu dosyalar silinebilir.

# %%
import os
import cv2
import shutil

# Orijinal veri seti dizinleri
cat_dir = "/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Cat"
dog_dir = "/kaggle/input/microsoft-catsvsdogs-dataset/PetImages/Dog"

# Temiz veri seti için yeni klasör
clean_base = "/kaggle/working/cats_and_dogs_clean"
os.makedirs(clean_base, exist_ok=True)

def copy_good_images(src_folder, dest_folder):
    os.makedirs(dest_folder, exist_ok=True)
    for file in os.listdir(src_folder):
        src_path = os.path.join(src_folder, file)
        try:
            img = cv2.imread(src_path)
            if img is not None:
                shutil.copy(src_path, dest_folder)
        except:
            continue

# Kedi ve köpek resimlerini temiz klasöre kopyala
copy_good_images(cat_dir, os.path.join(clean_base, "Cat"))
copy_good_images(dog_dir, os.path.join(clean_base, "Dog"))

print("Temiz veri klasörü hazır:", clean_base)
# Out:
# Corrupt JPEG data: 239 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 99 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 214 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 128 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1153 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 226 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 65 extraneous bytes before marker 0xd9
# Warning: unknown JFIF revision number 0.00
# Corrupt JPEG data: 254 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 1403 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 162 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 2230 extraneous bytes before marker 0xd9
# Corrupt JPEG data: 399 extraneous bytes before marker 0xd9
# Temiz veri klasörü hazır: /kaggle/working/cats_and_dogs_clean

# %% [markdown]
# Bu hücre, Kaggle input dizini **salt okunur** olduğu için bozuk dosyaları silmek yerine, sağlam görselleri yeni bir klasöre kopyalar.
# Sonuç olarak, bozuk dosyalar filtrelenmiş ve model eğitimi için hazır bir veri seti oluşturulur.

# %%
import os
import shutil
import random

random.seed(42)

split_base = "/kaggle/working/cats_and_dogs_split"
for folder in ["train", "val", "test"]:
    for label in ["Cat", "Dog"]:
        os.makedirs(os.path.join(split_base, folder, label), exist_ok=True)

for label in ["Cat", "Dog"]:
    files = os.listdir(os.path.join(clean_base, label))
    random.shuffle(files)
    n = len(files)
    train_end = int(0.7 * n)
    val_end = int(0.85 * n)

    for i, file in enumerate(files):
        src = os.path.join(clean_base, label, file)
        if i < train_end:
            dst = os.path.join(split_base, "train", label, file)
        elif i < val_end:
            dst = os.path.join(split_base, "val", label, file)
        else:
            dst = os.path.join(split_base, "test", label, file)
        shutil.copy(src, dst)

print("Train/Validation/Test ayrımı tamamlandı!")
# Out:
# Train/Validation/Test ayrımı tamamlandı!

# %% [markdown]
# Klasör yapısı:
#
# /kaggle/working/cats_and_dogs_clean
#     ├── Cat
#     └── Dog
# /kaggle/working/cats_and_dogs_split/
#     ├── train/
#     │     ├── Cat/
#     │     └── Dog/
#     ├── val/
#     │     ├── Cat/
#     │     └── Dog/
#     └── test/
#           ├── Cat/
#           └── Dog/
#
# Bu hücre, temizlenmiş kedi ve köpek resimlerini eğitim, doğrulama ve test setlerine böler.
# %70 eğitim (`train`)
#   - %15 doğrulama (`val`)
#   - %15 test (`test`)
# - `shutil.copy` ile sağlam resimler ilgili alt klasörlere kopyalanır
#
# Sonuç olarak, model eğitimi için hazır bir veri seti yapısı elde edilir.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # 0=all, 1=info, 2=warning, 3=error

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Bu hücre, derin öğrenme modeli oluşturmak için gerekli kütüphaneleri yükler.
# TensorFlow uyarı mesajlarını gizler (sadece kritik hatalar görünür)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Train verisi için augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    zoom_range=0.15,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Validation ve test verisi için sadece rescale
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Dizinleri tanımla
train_dir = "/kaggle/working/cats_and_dogs_split/train"
val_dir = "/kaggle/working/cats_and_dogs_split/val"
test_dir = "/kaggle/working/cats_and_dogs_split/test"

# Data generatorları oluştur
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary'
)

val_generator = val_test_datagen.flow_from_directory(
    val_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary'
)

test_generator = val_test_datagen.flow_from_directory(
    test_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 17462 images belonging to 2 classes.
# Found 3741 images belonging to 2 classes.
# Found 3743 images belonging to 2 classes.

# %% [markdown]
# Bu hücre, modelin eğitimi için veri üreteçlerini (generators) hazırlar.
# Bu yapı ile model, veriyi memory’ye yüklemeden, batch batch eğitilebilir.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # binary classification için
])

model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1758827122.989544      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1758827122.990209      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 36992)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    18,940,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,034,177 (72.61 MB)
#  Trainable params: 19,034,177 (72.61 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Bu çıktı, modelin doğru şekilde oluşturulduğunu ve eğitime hazır olduğunu gösterir.
# Model Mimarisi (Sequential), Model Derleme ve Model Özeti kısımlarını içerir.

# %%
# Modeli eğit
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=val_generator,
    validation_steps=val_generator.samples // val_generator.batch_size,
    epochs=10  # Dilersen 15-20 yapabilirsin
)

# Accuracy grafiği
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Loss grafiği
plt.figure(figsize=(8,4))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1758827371.080067     120 service.cc:148] XLA service 0x780bf00061b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1758827371.081079     120 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1758827371.081103     120 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1758827371.450309     120 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/545 ━━━━━━━━━━━━━━━━━━━━ 1:02:54 7s/step - accuracy: 0.5000 - loss: 0.7064
# I0000 00:00:1758827375.581147     120 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 274/545 ━━━━━━━━━━━━━━━━━━━━ 50s 187ms/step - accuracy: 0.5225 - loss: 0.7406
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 112s 194ms/step - accuracy: 0.5361 - loss: 0.7164 - val_accuracy: 0.6630 - val_loss: 0.6318
# Epoch 2/10
#   1/545 ━━━━━━━━━━━━━━━━━━━━ 17s 33ms/step - accuracy: 0.5938 - loss: 0.6819
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.5938 - loss: 0.6819 - val_accuracy: 0.6600 - val_loss: 0.6360
# Epoch 3/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 102s 187ms/step - accuracy: 0.6423 - loss: 0.6347 - val_accuracy: 0.7131 - val_loss: 0.5454
# Epoch 4/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6562 - loss: 0.5963 - val_accuracy: 0.7055 - val_loss: 0.5541
# Epoch 5/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 102s 187ms/step - accuracy: 0.6879 - loss: 0.5910 - val_accuracy: 0.7220 - val_loss: 0.5574
# Epoch 6/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.6875 - loss: 0.6824 - val_accuracy: 0.7349 - val_loss: 0.5516
# Epoch 7/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 101s 185ms/step - accuracy: 0.7190 - loss: 0.5545 - val_accuracy: 0.7874 - val_loss: 0.4583
# Epoch 8/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.7188 - loss: 0.6900 - val_accuracy: 0.7866 - val_loss: 0.4608
# Epoch 9/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 102s 187ms/step - accuracy: 0.7482 - loss: 0.5104 - val_accuracy: 0.7680 - val_loss: 0.4740
# Epoch 10/10
# 545/545 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.7500 - loss: 0.5666 - val_accuracy: 0.7775 - val_loss: 0.4626

# %% [markdown]
# ### Model Eğitimi ve Eğitim Grafikleri
#
# 1. **Model Fit:**
#    - `train_generator` ve `val_generator` kullanılarak model 10 epoch boyunca eğitilir
#    - `steps_per_epoch` ve `validation_steps` batch sayısına göre hesaplanır
#
# 2. **Accuracy Grafiği:**
#    - `history.history['accuracy']` → eğitim doğruluğu
#    - `history.history['val_accuracy']` → doğrulama doğruluğu
#    - Epoch ilerledikçe modelin performansı gözlemlenir
#
# 3. **Loss Grafiği:**
#    - `history.history['loss']` → eğitim kaybı
#    - `history.history['val_loss']` → doğrulama kaybı
#    - Modelin öğrenme durumu ve overfitting kontrolü yapılabilir
#
# Bu görselleştirmeler ile modelin eğitim süreci detaylı olarak izlenebilir.

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Test seti üzerinde tahmin yap
y_pred = model.predict(test_generator)
y_pred_classes = np.where(y_pred > 0.5, 1, 0)

# Gerçek etiketler
y_true = test_generator.classes

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Cat','Dog'], yticklabels=['Cat','Dog'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print(classification_report(y_true, y_pred_classes, target_names=['Cat','Dog']))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step
#               precision    recall  f1-score   support
#
#          Cat       0.74      0.87      0.80      1872
#          Dog       0.84      0.70      0.77      1871
#
#     accuracy                           0.78      3743
#    macro avg       0.79      0.78      0.78      3743
# weighted avg       0.79      0.78      0.78      3743

# %% [markdown]
# ### Test Seti ile Model Değerlendirme
#
# 1. **Tahmin Yapma:**
#    - `model.predict(test_generator)` ile test verisi üzerinde tahminler alınır
#    - `y_pred_classes` ile tahminler 0 veya 1 olarak binary sınıflara çevrilir
#
# 2. **Confusion Matrix (Karmaşıklık Matrisi):**
#    - Modelin doğru ve yanlış tahminleri görselleştirilir
#    - `sns.heatmap` ile kolay okunabilir bir matris çizilir
#
# 3. **Classification Report:**
#    - `precision`, `recall`, `f1-score` ve `support` değerleri hesaplanır
#    - Hangi sınıfta modelin performansının daha iyi olduğunu gösterir
#
# Bu adım modelin gerçek test verisi üzerindeki başarısını detaylı olarak analiz eder.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Model

def get_img_array(img_path, size):
    # Görüntüyü oku ve boyutlandır
    img = tf.keras.utils.load_img(img_path, target_size=size)
    array = tf.keras.utils.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    array /= 255.0
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]
    
    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0,1,2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

def display_gradcam(img_path, heatmap, alpha=0.4):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    heatmap_color = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    superimposed_img = cv2.addWeighted(img, 1-alpha, heatmap_color, alpha, 0)
    
    plt.figure(figsize=(6,6))
    plt.imshow(superimposed_img)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ### Grad-CAM Görselleştirmesi için Fonksiyonlar
#
# 1. **Görseli Hazırlama (`get_img_array`)**
#    - Görseli okur, `target_size` ile boyutlandırır ve 0-1 arasında normalize eder
#
# 2. **Grad-CAM Isı Haritası Üretme (`make_gradcam_heatmap`)**
#    - Son konvolüsyon katmanı üzerinden sınıf aktivasyonlarını hesaplar
#    - Grad-CAM tekniği ile hangi bölgelerin sınıf tahminine etkili olduğunu görselleştirmek için ısı haritası üretir
#
# 3. **Grad-CAM Görselleştirme (`display_gradcam`)**
#    - Orijinal görsel ile ısı haritasını üst üste bindirir
#    - `alpha` parametresi ile ısı haritasının şeffaflığı ayarlanabilir
#
# Bu fonksiyonlar sayesinde modelin hangi bölgelere dikkat ederek tahmin yaptığını görselleştirebilirsin.

# %%
import os

# Test Cat ve Dog klasöründeki dosyaları listele
cat_test_files = os.listdir("/kaggle/working/cats_and_dogs_split/test/Cat")
dog_test_files = os.listdir("/kaggle/working/cats_and_dogs_split/test/Dog")

# Örnek olarak ilk Cat görselini seç
img_path = "/kaggle/working/cats_and_dogs_split/test/Cat/" + cat_test_files[0]

print("Grad-CAM uygulanacak görsel:", img_path)
# Out:
# Grad-CAM uygulanacak görsel: /kaggle/working/cats_and_dogs_split/test/Cat/254.jpg

# %% [markdown]
# ### Grad-CAM için Örnek Görsel Seçimi
#
# 1. **Test Setindeki Görsellerin Listelenmesi:**
#    - Cat ve Dog klasörlerindeki dosyalar `os.listdir` ile alınır
#
# 2. **Örnek Görsel Seçimi:**
#    - İlk Cat görseli örnek olarak seçilir
#    - `img_path` değişkeni ile Grad-CAM uygulanacak görselin yolu belirlenir
#
# 3. **Bilgilendirme:**
#    - `print` ile seçilen görselin yolu gösterilir

# %%
import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model

# Görseli oku ve boyutlandır
def get_img_array(img_path, size=(150,150)):
    img = tf.keras.utils.load_img(img_path, target_size=size)
    array = tf.keras.utils.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    array /= 255.0
    return array

# Grad-CAM heatmap oluştur
def make_gradcam_heatmap(img_array, model, last_conv_layer_name, pred_index=None):
    grad_model = Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        if pred_index is None:
            pred_index = tf.argmax(predictions[0])
        class_channel = predictions[:, pred_index]

    grads = tape.gradient(class_channel, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0,1,2))
    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# Grad-CAM görselleştir
def display_gradcam(img_path, heatmap, alpha=0.4):
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ## Grad-CAM ile Görsel Analizi
#
# Modelin tahminlerde hangi bölgelere dikkat ettiğini görselleştirmek için Grad-CAM yöntemi kullanılmıştır.

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Görseli array’e çevir
img_array = get_img_array(img_path, size=(150,150))


# Modelden tahmin al (bu aynı zamanda modelin çağrılmasını sağlar)
preds = model.predict(img_array)
print("Tahmin:", preds)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 732ms/step
# Tahmin: [[0.09125093]]

# %% [markdown]
# ## Tek Görsel Tahmini
#
# Seçilen test görseli modelden geçirilmiş ve tahmin sonucu ekrana yazdırılmıştır.
#
# - Çıktı: `0.09125093` → Model bu görselin **Cat** olma olasılığını %9.1 olarak tahmin etti.

# %%
import os

test_cat_dir = "/kaggle/working/cats_and_dogs_split/test/Cat"
test_imgs = os.listdir(test_cat_dir)
img_path = os.path.join(test_cat_dir, test_imgs[0])  # klasördeki ilk Cat görseli

# %% [markdown]
# Test veri klasöründeki bir kedi görselini alıyoruz.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 1️⃣ ImageDataGenerator ile veri hazırlama
train_dir = "/kaggle/working/cats_vs_dogs_split/train"
test_dir = "/kaggle/working/cats_vs_dogs_split/test"

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary'
)

# 2️⃣ Functional API ile model tanımlama
inputs = Input(shape=(150,150,3))
x = Conv2D(32, (3,3), activation='relu')(inputs)
x = MaxPooling2D((2,2))(x)
x = Conv2D(64, (3,3), activation='relu')(x)
x = MaxPooling2D((2,2))(x)
x = Conv2D(128, (3,3), activation='relu', name='last_conv')(x)
x = MaxPooling2D((2,2))(x)
x = Flatten()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)
outputs = Dense(1, activation='sigmoid')(x)

model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# 3️⃣ Modeli eğit
history = model.fit(
    train_generator,
    epochs=5,
    validation_data=test_generator
)
# Out:
# Found 19996 images belonging to 2 classes.
# Found 5002 images belonging to 2 classes.
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 128s 200ms/step - accuracy: 0.5799 - loss: 0.6938 - val_accuracy: 0.7047 - val_loss: 0.5730
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 118s 189ms/step - accuracy: 0.6810 - loss: 0.5913 - val_accuracy: 0.7525 - val_loss: 0.5155
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 117s 187ms/step - accuracy: 0.7293 - loss: 0.5366 - val_accuracy: 0.7597 - val_loss: 0.4960
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 118s 189ms/step - accuracy: 0.7480 - loss: 0.5107 - val_accuracy: 0.8103 - val_loss: 0.4199
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 119s 190ms/step - accuracy: 0.7698 - loss: 0.4824 - val_accuracy: 0.8183 - val_loss: 0.4072

# %% [markdown]
# # Cats vs Dogs Sınıflandırma Projesi
#
# ## 1️⃣ Veri Hazırlama
# - `ImageDataGenerator` ile eğitim ve test verilerini hazırlıyoruz.
# - Eğitim verisi için veri artırma (augmentation) uygulandı: döndürme, kaydırma, zoom, yatay çevirme vb.
# - Test verisi sadece normalizasyon (rescale) uygulandı.
#
# ## 2️⃣ Model Tanımlama
# - Functional API kullanarak basit bir Convolutional Neural Network (CNN) oluşturuldu.
# - Katmanlar:
#   - 3 adet Conv2D + MaxPooling
#   - Flatten
#   - Dense katmanı (512 nöron, ReLU)
#   - Dropout (0.5)
#   - Çıkış katmanı: 1 nöron, sigmoid (binary sınıflama)
#
# ## 3️⃣ Model Eğitimi
# - Model `binary_crossentropy` loss ve `adam` optimizer ile derlendi.
# - 5 epoch boyunca eğitim ve doğrulama seti ile eğitildi.
# - `history` değişkeni ile eğitim sürecinde loss ve accuracy değerleri takip edildi.

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# Test klasöründeki görsellerden birini al
test_cat_folder = "/kaggle/working/cats_vs_dogs_split/test/Cat"
test_images = os.listdir(test_cat_folder)
img_path = os.path.join(test_cat_folder, test_images[0])  # ilk görseli al

# 1️⃣ Görseli yükleme ve diziye çevirme
def get_img_array(img_path, size=(150, 150)):
    img = image.load_img(img_path, target_size=size)
    array = image.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    return array

# 2️⃣ Grad-CAM hesaplama
def make_gradcam_heatmap(img_array, model, last_conv_layer_name="last_conv"):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )

    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, 0]

    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    conv_outputs = conv_outputs[0]
    heatmap = conv_outputs @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap.numpy()

# 3️⃣ Grad-CAM görselleştirme
def display_gradcam(img_path, heatmap, alpha=0.4):
    img = image.load_img(img_path)
    img = image.img_to_array(img).astype(np.uint8)

    heatmap = tf.image.resize(heatmap[..., np.newaxis], (img.shape[0], img.shape[1]))
    heatmap = np.uint8(255 * heatmap)
    heatmap = np.repeat(heatmap, 3, axis=-1)

    superimposed_img = img * (1 - alpha) + heatmap * alpha
    superimposed_img = np.uint8(superimposed_img)

    plt.figure(figsize=(6,6))
    plt.imshow(superimposed_img)
    plt.axis("off")
    plt.show()

# 4️⃣ Çalıştır
img_array = get_img_array(img_path)
heatmap = make_gradcam_heatmap(img_array, model)
display_gradcam(img_path, heatmap)
# Out:
# /tmp/ipykernel_36/1278138492.py:44: RuntimeWarning: invalid value encountered in cast
#   heatmap = np.uint8(255 * heatmap)

# %% [markdown]
# ## Tek Görsel için Grad-CAM Uygulaması
#
# ### 1️⃣ Test Görselini Hazırlama
# - Test klasöründen bir kedi görseli seçildi.
# - `get_img_array` fonksiyonu ile görsel 150x150 boyutuna ölçeklendi ve array'e çevrildi.
#
# ### 2️⃣ Grad-CAM Hesaplama
# - `make_gradcam_heatmap` fonksiyonu:
#   - Modelin son Conv2D katmanının çıktısını ve tahminini alıyor.
#   - Grad-CAM algoritması ile görselin hangi bölgelerinin tahminde etkili olduğunu belirliyor.
#   - Çıktı olarak 0-1 aralığında bir heatmap üretiyor.
#
# ### 3️⃣ Grad-CAM Görselleştirme
# - `display_gradcam` fonksiyonu:
#   - Orijinal görsel ile heatmap’i birleştiriyor.
#   - Sonucu matplotlib ile ekranda gösteriyor.
#
# ### 4️⃣ Çalıştırma
# - Seçilen görsel array'e çevrilip Grad-CAM heatmap'i oluşturuldu ve görselleştirildi.

# %%
import os

test_cat_folder = "/kaggle/working/cats_vs_dogs_split/test/Cat"
# Test klasöründeki ilk görseli seç
img_file = os.listdir(test_cat_folder)[0]
img_path = os.path.join(test_cat_folder, img_file)

# Sonra Grad-CAM kodunu kullanabiliriz
img_array = get_img_array(img_path)
heatmap = make_gradcam_heatmap(img_array, model)
display_gradcam(img_path, heatmap)
# Out:
# /tmp/ipykernel_36/1278138492.py:44: RuntimeWarning: invalid value encountered in cast
#   heatmap = np.uint8(255 * heatmap)

# %% [markdown]
# ## Tek Görsel Seçimi ve Grad-CAM Uygulama
#
# - Test klasöründen ilk kedi görseli seçildi.
# - `get_img_array` ile görsel array'e çevrildi.
# - `make_gradcam_heatmap` ile heatmap hesaplandı.
# - `display_gradcam` ile görsel üzerine heatmap uygulanıp gösterildi.

# %%
import os

test_cat_folder = "/kaggle/working/cats_vs_dogs_split/test/Cat"
# Test klasöründeki ilk görseli seç
img_file = os.listdir(test_cat_folder)[0]
img_path = os.path.join(test_cat_folder, img_file)

# Sonra Grad-CAM kodunu kullanabiliriz
img_array = get_img_array(img_path)
heatmap = make_gradcam_heatmap(img_array, model)
display_gradcam(img_path, heatmap)
# Out:
# /tmp/ipykernel_36/1278138492.py:44: RuntimeWarning: invalid value encountered in cast
#   heatmap = np.uint8(255 * heatmap)

# %% [markdown]
# ## Test Görseli ile Grad-CAM Uygulaması
#
# - Test klasöründen ilk kedi görseli seçildi.
# - Görsel array formatına dönüştürüldü (`get_img_array`).
# - Grad-CAM heatmap hesaplandı (`make_gradcam_heatmap`).
# - Heatmap görsel üzerine uygulanıp görüntülendi (`display_gradcam`).

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing import image

# Test klasörleri
test_folder = "/kaggle/working/cats_vs_dogs_split/test"
output_folder = "/kaggle/working/gradcam_results"

# Klasörleri oluştur
for category in ["Cat", "Dog"]:
    os.makedirs(os.path.join(output_folder, category), exist_ok=True)

def get_img_array(img_path, target_size=(150,150)):
    img = image.load_img(img_path, target_size=target_size)
    array = image.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    array = array / 255.0
    return array

def make_gradcam_heatmap(img_array, model, last_conv_layer_name="last_conv"):
    grad_model = tf.keras.models.Model(
        [model.inputs], [model.get_layer(last_conv_layer_name).output, model.output]
    )
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_array)
        loss = predictions[:, 0]
    grads = tape.gradient(loss, conv_outputs)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs = conv_outputs[0]
    heatmap = tf.reduce_mean(tf.multiply(conv_outputs, pooled_grads), axis=-1)
    heatmap = np.maximum(heatmap, 0)
    heatmap /= tf.reduce_max(heatmap) if tf.reduce_max(heatmap) != 0 else 1
    heatmap = np.uint8(255 * heatmap)
    return heatmap

def display_gradcam(img_path, heatmap, alpha=0.4):
    img = image.load_img(img_path)
    img = image.img_to_array(img).astype(np.uint8)
    heatmap = np.expand_dims(heatmap, axis=-1)
    heatmap = np.repeat(heatmap, 3, axis=-1)
    superimposed_img = heatmap * alpha + img
    superimposed_img = np.clip(superimposed_img, 0, 255).astype(np.uint8)
    return superimposed_img

# Burada model değişkenini doğrudan kullanıyoruz, tekrar load_model yok
for category in ["Cat", "Dog"]:
    category_folder = os.path.join(test_folder, category)
    for img_file in os.listdir(category_folder):
        img_path = os.path.join(category_folder, img_file)
        try:
            img_array = get_img_array(img_path)
            heatmap = make_gradcam_heatmap(img_array, model)
            superimposed_img = display_gradcam(img_path, heatmap)
            
            save_path = os.path.join(output_folder, category, img_file)
            plt.imsave(save_path, superimposed_img)
        except Exception as e:
            print(f"Atlandı: {img_path} ({e})")
            continue

print("Tüm test görselleri için Grad-CAM oluşturuldu ve kaydedildi.")
# Out:
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11747.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5453.jpg (operands could not be broadcast together with shapes (34,34,3) (480,376,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/253.jpg (operands could not be broadcast together with shapes (34,34,3) (129,154,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/17.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10245.jpg (operands could not be broadcast together with shapes (34,34,3) (469,460,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3388.jpg (operands could not be broadcast together with shapes (34,34,3) (378,450,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7147.jpg (operands could not be broadcast together with shapes (34,34,3) (500,332,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3702.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4979.jpg (operands could not be broadcast together with shapes (34,34,3) (500,400,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10008.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2239.jpg (operands could not be broadcast together with shapes (34,34,3) (247,298,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1102.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12162.jpg (operands could not be broadcast together with shapes (34,34,3) (500,299,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5763.jpg (operands could not be broadcast together with shapes (34,34,3) (180,200,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12010.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4622.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4346.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7690.jpg (operands could not be broadcast together with shapes (34,34,3) (321,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3560.jpg (operands could not be broadcast together with shapes (34,34,3) (435,331,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4631.jpg (operands could not be broadcast together with shapes (34,34,3) (336,447,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9352.jpg (operands could not be broadcast together with shapes (34,34,3) (279,450,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6566.jpg (operands could not be broadcast together with shapes (34,34,3) (440,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7242.jpg (operands could not be broadcast together with shapes (34,34,3) (330,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7395.jpg (operands could not be broadcast together with shapes (34,34,3) (400,400,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5833.jpg (operands could not be broadcast together with shapes (34,34,3) (192,288,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3865.jpg (operands could not be broadcast together with shapes (34,34,3) (240,307,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3910.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9941.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/393.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3643.jpg (operands could not be broadcast together with shapes (34,34,3) (292,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11139.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8904.jpg (operands could not be broadcast together with shapes (34,34,3) (491,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8573.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7710.jpg (operands could not be broadcast together with shapes (34,34,3) (345,400,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/695.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10371.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8877.jpg (operands could not be broadcast together with shapes (34,34,3) (150,200,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6116.jpg (operands could not be broadcast together with shapes (34,34,3) (232,247,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1107.jpg (operands could not be broadcast together with shapes (34,34,3) (500,434,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9774.jpg (operands could not be broadcast together with shapes (34,34,3) (377,400,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1416.jpg (operands could not be broadcast together with shapes (34,34,3) (438,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/205.jpg (operands could not be broadcast together with shapes (34,34,3) (259,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3809.jpg (operands could not be broadcast together with shapes (34,34,3) (500,379,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8448.jpg (operands could not be broadcast together with shapes (34,34,3) (84,160,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3476.jpg (operands could not be broadcast together with shapes (34,34,3) (500,314,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9004.jpg (operands could not be broadcast together with shapes (34,34,3) (324,321,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3217.jpg (operands could not be broadcast together with shapes (34,34,3) (427,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10418.jpg (operands could not be broadcast together with shapes (34,34,3) (190,99,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6002.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2901.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8004.jpg (operands could not be broadcast together with shapes (34,34,3) (262,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8279.jpg (operands could not be broadcast together with shapes (34,34,3) (500,410,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8921.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9745.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11676.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/592.jpg (operands could not be broadcast together with shapes (34,34,3) (477,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6125.jpg (operands could not be broadcast together with shapes (34,34,3) (199,220,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/157.jpg (operands could not be broadcast together with shapes (34,34,3) (250,250,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5916.jpg (operands could not be broadcast together with shapes (34,34,3) (371,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12309.jpg (operands could not be broadcast together with shapes (34,34,3) (271,204,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2970.jpg (operands could not be broadcast together with shapes (34,34,3) (287,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5682.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5312.jpg (operands could not be broadcast together with shapes (34,34,3) (362,463,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5741.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6526.jpg (operands could not be broadcast together with shapes (34,34,3) (371,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/382.jpg (operands could not be broadcast together with shapes (34,34,3) (144,216,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10455.jpg (operands could not be broadcast together with shapes (34,34,3) (500,469,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1594.jpg (operands could not be broadcast together with shapes (34,34,3) (250,250,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5818.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12290.jpg (operands could not be broadcast together with shapes (34,34,3) (473,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3226.jpg (operands could not be broadcast together with shapes (34,34,3) (231,250,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4772.jpg (operands could not be broadcast together with shapes (34,34,3) (356,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2168.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10478.jpg (operands could not be broadcast together with shapes (34,34,3) (375,476,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8534.jpg (operands could not be broadcast together with shapes (34,34,3) (102,100,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11313.jpg (operands could not be broadcast together with shapes (34,34,3) (448,281,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6194.jpg (operands could not be broadcast together with shapes (34,34,3) (355,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8068.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1864.jpg (operands could not be broadcast together with shapes (34,34,3) (426,478,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7049.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10098.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10764.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3232.jpg (operands could not be broadcast together with shapes (34,34,3) (500,352,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2879.jpg (operands could not be broadcast together with shapes (34,34,3) (500,302,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8147.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5219.jpg (operands could not be broadcast together with shapes (34,34,3) (301,460,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11159.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11328.jpg (operands could not be broadcast together with shapes (34,34,3) (300,470,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4094.jpg (operands could not be broadcast together with shapes (34,34,3) (159,185,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9985.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11578.jpg (operands could not be broadcast together with shapes (34,34,3) (500,449,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6631.jpg (operands could not be broadcast together with shapes (34,34,3) (225,300,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11932.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9700.jpg (operands could not be broadcast together with shapes (34,34,3) (360,448,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8805.jpg (operands could not be broadcast together with shapes (34,34,3) (267,252,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8406.jpg (operands could not be broadcast together with shapes (34,34,3) (393,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2178.jpg (operands could not be broadcast together with shapes (34,34,3) (249,450,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6756.jpg (operands could not be broadcast together with shapes (34,34,3) (300,400,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11499.jpg (operands could not be broadcast together with shapes (34,34,3) (150,150,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6548.jpg (operands could not be broadcast together with shapes (34,34,3) (175,202,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/850.jpg (operands could not be broadcast together with shapes (34,34,3) (346,259,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6109.jpg (operands could not be broadcast together with shapes (34,34,3) (383,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6921.jpg (operands could not be broadcast together with shapes (34,34,3) (331,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/902.jpg (operands could not be broadcast together with shapes (34,34,3) (331,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/512.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9665.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/520.jpg (operands could not be broadcast together with shapes (34,34,3) (302,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/139.jpg (operands could not be broadcast together with shapes (34,34,3) (303,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5520.jpg (operands could not be broadcast together with shapes (34,34,3) (278,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3392.jpg (operands could not be broadcast together with shapes (34,34,3) (500,462,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6008.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3364.jpg (operands could not be broadcast together with shapes (34,34,3) (379,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10858.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1617.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6260.jpg (operands could not be broadcast together with shapes (34,34,3) (349,336,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9919.jpg (operands could not be broadcast together with shapes (34,34,3) (420,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9865.jpg (operands could not be broadcast together with shapes (34,34,3) (270,272,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4823.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8342.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4138.jpg (operands could not be broadcast together with shapes (34,34,3) (500,349,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3365.jpg (operands could not be broadcast together with shapes (34,34,3) (394,336,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8622.jpg (operands could not be broadcast together with shapes (34,34,3) (128,192,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7837.jpg (operands could not be broadcast together with shapes (34,34,3) (363,419,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1573.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8813.jpg (operands could not be broadcast together with shapes (34,34,3) (500,450,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3417.jpg (operands could not be broadcast together with shapes (34,34,3) (242,325,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10576.jpg (operands could not be broadcast together with shapes (34,34,3) (398,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9809.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2862.jpg (operands could not be broadcast together with shapes (34,34,3) (500,420,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4637.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10173.jpg (operands could not be broadcast together with shapes (34,34,3) (310,432,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7670.jpg (operands could not be broadcast together with shapes (34,34,3) (396,358,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2314.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1824.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/853.jpg (operands could not be broadcast together with shapes (34,34,3) (226,276,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12164.jpg (operands could not be broadcast together with shapes (34,34,3) (270,360,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5392.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4143.jpg (operands could not be broadcast together with shapes (34,34,3) (346,288,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2145.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7859.jpg (operands could not be broadcast together with shapes (34,34,3) (500,374,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2783.jpg (operands could not be broadcast together with shapes (34,34,3) (204,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/356.jpg (operands could not be broadcast together with shapes (34,34,3) (405,450,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11317.jpg (operands could not be broadcast together with shapes (34,34,3) (190,205,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3184.jpg (operands could not be broadcast together with shapes (34,34,3) (366,400,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10551.jpg (operands could not be broadcast together with shapes (34,34,3) (242,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6868.jpg (operands could not be broadcast together with shapes (34,34,3) (106,160,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6202.jpg (operands could not be broadcast together with shapes (34,34,3) (500,444,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2530.jpg (operands could not be broadcast together with shapes (34,34,3) (374,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3840.jpg (operands could not be broadcast together with shapes (34,34,3) (338,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5276.jpg (operands could not be broadcast together with shapes (34,34,3) (305,450,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5405.jpg (operands could not be broadcast together with shapes (34,34,3) (474,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/956.jpg (operands could not be broadcast together with shapes (34,34,3) (263,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6588.jpg (operands could not be broadcast together with shapes (34,34,3) (500,334,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7219.jpg (operands could not be broadcast together with shapes (34,34,3) (371,479,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10158.jpg (operands could not be broadcast together with shapes (34,34,3) (500,442,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/416.jpg (operands could not be broadcast together with shapes (34,34,3) (163,150,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3053.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9779.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5057.jpg (operands could not be broadcast together with shapes (34,34,3) (478,386,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10148.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9232.jpg (operands could not be broadcast together with shapes (34,34,3) (332,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8893.jpg (operands could not be broadcast together with shapes (34,34,3) (350,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3913.jpg (operands could not be broadcast together with shapes (34,34,3) (458,448,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9349.jpg (operands could not be broadcast together with shapes (34,34,3) (240,280,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/979.jpg (operands could not be broadcast together with shapes (34,34,3) (456,330,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5561.jpg (operands could not be broadcast together with shapes (34,34,3) (402,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4021.jpg (operands could not be broadcast together with shapes (34,34,3) (311,400,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10028.jpg (operands could not be broadcast together with shapes (34,34,3) (135,180,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1740.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4035.jpg (operands could not be broadcast together with shapes (34,34,3) (267,288,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11922.jpg (operands could not be broadcast together with shapes (34,34,3) (321,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9686.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9191.jpg (operands could not be broadcast together with shapes (34,34,3) (357,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5263.jpg (operands could not be broadcast together with shapes (34,34,3) (456,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8931.jpg (operands could not be broadcast together with shapes (34,34,3) (407,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9412.jpg (operands could not be broadcast together with shapes (34,34,3) (500,305,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2998.jpg (operands could not be broadcast together with shapes (34,34,3) (349,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12301.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5658.jpg (operands could not be broadcast together with shapes (34,34,3) (438,390,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8662.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7191.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1813.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12333.jpg (operands could not be broadcast together with shapes (34,34,3) (216,200,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9785.jpg (operands could not be broadcast together with shapes (34,34,3) (377,499,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7654.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10124.jpg (operands could not be broadcast together with shapes (34,34,3) (338,450,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3481.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12231.jpg (operands could not be broadcast together with shapes (34,34,3) (500,467,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1153.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5328.jpg (operands could not be broadcast together with shapes (34,34,3) (225,300,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5366.jpg (operands could not be broadcast together with shapes (34,34,3) (107,156,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6985.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8227.jpg (operands could not be broadcast together with shapes (34,34,3) (392,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/261.jpg (operands could not be broadcast together with shapes (34,34,3) (180,181,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5401.jpg (operands could not be broadcast together with shapes (34,34,3) (500,473,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5110.jpg (operands could not be broadcast together with shapes (34,34,3) (500,367,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6111.jpg (operands could not be broadcast together with shapes (34,34,3) (444,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11685.jpg (operands could not be broadcast together with shapes (34,34,3) (407,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5411.jpg (operands could not be broadcast together with shapes (34,34,3) (226,432,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9209.jpg (operands could not be broadcast together with shapes (34,34,3) (500,323,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11061.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3494.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8555.jpg (operands could not be broadcast together with shapes (34,34,3) (319,488,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6770.jpg (operands could not be broadcast together with shapes (34,34,3) (429,453,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7579.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9878.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9582.jpg (operands could not be broadcast together with shapes (34,34,3) (476,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1832.jpg (operands could not be broadcast together with shapes (34,34,3) (500,448,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/99.jpg (operands could not be broadcast together with shapes (34,34,3) (175,226,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9426.jpg (operands could not be broadcast together with shapes (34,34,3) (329,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8320.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7758.jpg (operands could not be broadcast together with shapes (34,34,3) (140,300,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3657.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8138.jpg (operands could not be broadcast together with shapes (34,34,3) (71,96,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1086.jpg (operands could not be broadcast together with shapes (34,34,3) (436,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7783.jpg (operands could not be broadcast together with shapes (34,34,3) (271,300,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/411.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11806.jpg (operands could not be broadcast together with shapes (34,34,3) (371,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4623.jpg (operands could not be broadcast together with shapes (34,34,3) (455,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5939.jpg (operands could not be broadcast together with shapes (34,34,3) (325,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3399.jpg (operands could not be broadcast together with shapes (34,34,3) (332,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/294.jpg (operands could not be broadcast together with shapes (34,34,3) (430,398,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4552.jpg (operands could not be broadcast together with shapes (34,34,3) (300,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2424.jpg (operands could not be broadcast together with shapes (34,34,3) (152,250,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7847.jpg (operands could not be broadcast together with shapes (34,34,3) (187,250,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4685.jpg (operands could not be broadcast together with shapes (34,34,3) (500,356,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12316.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3439.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/3658.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7065.jpg (operands could not be broadcast together with shapes (34,34,3) (220,216,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8779.jpg (operands could not be broadcast together with shapes (34,34,3) (500,335,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2721.jpg (operands could not be broadcast together with shapes (34,34,3) (448,479,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1173.jpg (operands could not be broadcast together with shapes (34,34,3) (400,300,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2057.jpg (operands could not be broadcast together with shapes (34,34,3) (360,400,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11726.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11560.jpg (operands could not be broadcast together with shapes (34,34,3) (346,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2232.jpg (operands could not be broadcast together with shapes (34,34,3) (500,402,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12139.jpg (operands could not be broadcast together with shapes (34,34,3) (199,220,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5614.jpg (operands could not be broadcast together with shapes (34,34,3) (422,490,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10469.jpg (operands could not be broadcast together with shapes (34,34,3) (379,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7060.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2722.jpg (operands could not be broadcast together with shapes (34,34,3) (233,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9359.jpg (operands could not be broadcast together with shapes (34,34,3) (188,380,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2878.jpg (operands could not be broadcast together with shapes (34,34,3) (199,220,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9334.jpg (operands could not be broadcast together with shapes (34,34,3) (253,187,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8749.jpg (operands could not be broadcast together with shapes (34,34,3) (89,120,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10313.jpg (operands could not be broadcast together with shapes (34,34,3) (263,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10069.jpg (operands could not be broadcast together with shapes (34,34,3) (391,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6341.jpg (operands could not be broadcast together with shapes (34,34,3) (289,259,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1874.jpg (operands could not be broadcast together with shapes (34,34,3) (142,119,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12072.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8822.jpg (operands could not be broadcast together with shapes (34,34,3) (500,486,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2167.jpg (operands could not be broadcast together with shapes (34,34,3) (230,319,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9042.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6989.jpg (operands could not be broadcast together with shapes (34,34,3) (271,235,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8347.jpg (operands could not be broadcast together with shapes (34,34,3) (366,336,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7949.jpg (operands could not be broadcast together with shapes (34,34,3) (416,414,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8371.jpg (operands could not be broadcast together with shapes (34,34,3) (424,371,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1627.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11937.jpg (operands could not be broadcast together with shapes (34,34,3) (437,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5541.jpg (operands could not be broadcast together with shapes (34,34,3) (336,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10479.jpg (operands could not be broadcast together with shapes (34,34,3) (282,372,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11290.jpg (operands could not be broadcast together with shapes (34,34,3) (346,190,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9753.jpg (operands could not be broadcast together with shapes (34,34,3) (126,200,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6760.jpg (operands could not be broadcast together with shapes (34,34,3) (476,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1553.jpg (operands could not be broadcast together with shapes (34,34,3) (420,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/522.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12006.jpg (operands could not be broadcast together with shapes (34,34,3) (409,307,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11515.jpg (operands could not be broadcast together with shapes (34,34,3) (233,418,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12304.jpg (operands could not be broadcast together with shapes (34,34,3) (223,195,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6141.jpg (operands could not be broadcast together with shapes (34,34,3) (500,371,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/734.jpg (operands could not be broadcast together with shapes (34,34,3) (500,348,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1515.jpg (operands could not be broadcast together with shapes (34,34,3) (408,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2208.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11206.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/12169.jpg (operands could not be broadcast together with shapes (34,34,3) (500,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8024.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2385.jpg (operands could not be broadcast together with shapes (34,34,3) (500,321,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9288.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6904.jpg (operands could not be broadcast together with shapes (34,34,3) (374,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11017.jpg (operands could not be broadcast together with shapes (34,34,3) (201,295,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6149.jpg (operands could not be broadcast together with shapes (34,34,3) (225,300,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2092.jpg (operands could not be broadcast together with shapes (34,34,3) (344,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5885.jpg (operands could not be broadcast together with shapes (34,34,3) (276,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11887.jpg (operands could not be broadcast together with shapes (34,34,3) (298,375,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10278.jpg (operands could not be broadcast together with shapes (34,34,3) (190,173,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11552.jpg (operands could not be broadcast together with shapes (34,34,3) (200,250,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9894.jpg (operands could not be broadcast together with shapes (34,34,3) (331,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8870.jpg (operands could not be broadcast together with shapes (34,34,3) (175,173,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11774.jpg (operands could not be broadcast together with shapes (34,34,3) (358,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11640.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9333.jpg (operands could not be broadcast together with shapes (34,34,3) (301,250,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6933.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1131.jpg (operands could not be broadcast together with shapes (34,34,3) (500,484,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5529.jpg (operands could not be broadcast together with shapes (34,34,3) (100,150,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6293.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7066.jpg (operands could not be broadcast together with shapes (34,34,3) (500,479,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1412.jpg (operands could not be broadcast together with shapes (34,34,3) (256,295,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5546.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7184.jpg (operands could not be broadcast together with shapes (34,34,3) (143,150,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11543.jpg (operands could not be broadcast together with shapes (34,34,3) (323,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2041.jpg (operands could not be broadcast together with shapes (34,34,3) (386,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11841.jpg (operands could not be broadcast together with shapes (34,34,3) (380,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5504.jpg (operands could not be broadcast together with shapes (34,34,3) (394,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6932.jpg (operands could not be broadcast together with shapes (34,34,3) (270,338,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9107.jpg (operands could not be broadcast together with shapes (34,34,3) (332,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10365.jpg (operands could not be broadcast together with shapes (34,34,3) (224,296,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1931.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/537.jpg (operands could not be broadcast together with shapes (34,34,3) (368,450,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/4532.jpg (operands could not be broadcast together with shapes (34,34,3) (395,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11340.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5169.jpg (operands could not be broadcast together with shapes (34,34,3) (182,185,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5731.jpg (operands could not be broadcast together with shapes (34,34,3) (374,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6883.jpg (operands could not be broadcast together with shapes (34,34,3) (361,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8953.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11287.jpg (operands could not be broadcast together with shapes (34,34,3) (230,470,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/993.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11536.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5170.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/1904.jpg (operands could not be broadcast together with shapes (34,34,3) (148,206,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/7797.jpg (operands could not be broadcast together with shapes (34,34,3) (500,353,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2824.jpg (operands could not be broadcast together with shapes (34,34,3) (453,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9251.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10237.jpg (operands could not be broadcast together with shapes (34,34,3) (500,295,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8533.jpg (operands could not be broadcast together with shapes (34,34,3) (310,410,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/11516.jpg (operands could not be broadcast together with shapes (34,34,3) (230,205,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2830.jpg (operands could not be broadcast together with shapes (34,34,3) (332,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6853.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6294.jpg (operands could not be broadcast together with shapes (34,34,3) (500,321,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5241.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6510.jpg (operands could not be broadcast together with shapes (34,34,3) (387,357,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/10673.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5698.jpg (operands could not be broadcast together with shapes (34,34,3) (427,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/5595.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9314.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/2741.jpg (operands could not be broadcast together with shapes (34,34,3) (386,352,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9238.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/8312.jpg (operands could not be broadcast together with shapes (34,34,3) (363,383,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9519.jpg (operands could not be broadcast together with shapes (34,34,3) (288,277,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/6171.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/9335.jpg (operands could not be broadcast together with shapes (34,34,3) (266,399,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Cat/914.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# ...
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10646.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/369.jpg (operands could not be broadcast together with shapes (34,34,3) (371,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/925.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/5428.jpg (operands could not be broadcast together with shapes (34,34,3) (313,371,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/12364.jpg (operands could not be broadcast together with shapes (34,34,3) (407,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/1986.jpg (operands could not be broadcast together with shapes (34,34,3) (316,275,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/8624.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/12107.jpg (operands could not be broadcast together with shapes (34,34,3) (393,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/3159.jpg (operands could not be broadcast together with shapes (34,34,3) (336,448,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/11353.jpg (operands could not be broadcast together with shapes (34,34,3) (224,299,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10254.jpg (operands could not be broadcast together with shapes (34,34,3) (236,218,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/771.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/8372.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/4190.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/1568.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10783.jpg (operands could not be broadcast together with shapes (34,34,3) (150,150,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/8632.jpg (operands could not be broadcast together with shapes (34,34,3) (137,144,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/6100.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/7635.jpg (operands could not be broadcast together with shapes (34,34,3) (400,264,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/3947.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/4962.jpg (operands could not be broadcast together with shapes (34,34,3) (346,359,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/6439.jpg (operands could not be broadcast together with shapes (34,34,3) (404,400,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/5128.jpg (operands could not be broadcast together with shapes (34,34,3) (80,123,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/4978.jpg (operands could not be broadcast together with shapes (34,34,3) (271,204,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10471.jpg (operands could not be broadcast together with shapes (34,34,3) (500,333,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10406.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/7386.jpg (operands could not be broadcast together with shapes (34,34,3) (383,469,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/1001.jpg (operands could not be broadcast together with shapes (34,34,3) (500,348,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/5326.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/923.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/7785.jpg (operands could not be broadcast together with shapes (34,34,3) (144,190,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/9735.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/2463.jpg (operands could not be broadcast together with shapes (34,34,3) (476,400,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/2520.jpg (operands could not be broadcast together with shapes (34,34,3) (500,424,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/1628.jpg (operands could not be broadcast together with shapes (34,34,3) (480,360,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/7720.jpg (operands could not be broadcast together with shapes (34,34,3) (382,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10247.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/7540.jpg (operands could not be broadcast together with shapes (34,34,3) (400,400,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/8794.jpg (operands could not be broadcast together with shapes (34,34,3) (420,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/7437.jpg (operands could not be broadcast together with shapes (34,34,3) (450,466,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/8562.jpg (operands could not be broadcast together with shapes (34,34,3) (452,380,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/3424.jpg (operands could not be broadcast together with shapes (34,34,3) (432,259,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/3050.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/6181.jpg (operands could not be broadcast together with shapes (34,34,3) (273,199,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/12330.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/4144.jpg (operands could not be broadcast together with shapes (34,34,3) (500,321,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/9859.jpg (operands could not be broadcast together with shapes (34,34,3) (356,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10104.jpg (operands could not be broadcast together with shapes (34,34,3) (285,380,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/8043.jpg (operands could not be broadcast together with shapes (34,34,3) (420,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/9783.jpg (operands could not be broadcast together with shapes (34,34,3) (438,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/7977.jpg (operands could not be broadcast together with shapes (34,34,3) (322,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/9398.jpg (operands could not be broadcast together with shapes (34,34,3) (234,310,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/8752.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10206.jpg (operands could not be broadcast together with shapes (34,34,3) (270,262,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/6787.jpg (operands could not be broadcast together with shapes (34,34,3) (373,425,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/11690.jpg (operands could not be broadcast together with shapes (34,34,3) (233,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/2504.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/8527.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/3405.jpg (operands could not be broadcast together with shapes (34,34,3) (396,336,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/2260.jpg (operands could not be broadcast together with shapes (34,34,3) (332,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10080.jpg (operands could not be broadcast together with shapes (34,34,3) (500,396,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/7313.jpg (operands could not be broadcast together with shapes (34,34,3) (390,333,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10725.jpg (operands could not be broadcast together with shapes (34,34,3) (376,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/348.jpg (operands could not be broadcast together with shapes (34,34,3) (247,300,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/3745.jpg (operands could not be broadcast together with shapes (34,34,3) (500,348,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/3721.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/6195.jpg (operands could not be broadcast together with shapes (34,34,3) (480,347,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/11454.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/4855.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/11966.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10307.jpg (operands could not be broadcast together with shapes (34,34,3) (334,324,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10304.jpg (operands could not be broadcast together with shapes (34,34,3) (334,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/1345.jpg (operands could not be broadcast together with shapes (34,34,3) (486,480,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/1223.jpg (operands could not be broadcast together with shapes (34,34,3) (500,380,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/3195.jpg (operands could not be broadcast together with shapes (34,34,3) (303,169,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/4676.jpg (operands could not be broadcast together with shapes (34,34,3) (422,335,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/8471.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10439.jpg (operands could not be broadcast together with shapes (34,34,3) (182,119,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/7256.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/9720.jpg (operands could not be broadcast together with shapes (34,34,3) (333,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/5915.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/6729.jpg (operands could not be broadcast together with shapes (34,34,3) (233,350,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/9508.jpg (operands could not be broadcast together with shapes (34,34,3) (477,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/7799.jpg (operands could not be broadcast together with shapes (34,34,3) (332,460,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/8695.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/4848.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/1184.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/1586.jpg (operands could not be broadcast together with shapes (34,34,3) (500,375,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/4290.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/1052.jpg (operands could not be broadcast together with shapes (34,34,3) (489,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10859.jpg (operands could not be broadcast together with shapes (34,34,3) (316,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/4262.jpg (operands could not be broadcast together with shapes (34,34,3) (380,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/855.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/2366.jpg (operands could not be broadcast together with shapes (34,34,3) (270,360,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/504.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/7952.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/2503.jpg (operands could not be broadcast together with shapes (34,34,3) (469,200,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/9485.jpg (operands could not be broadcast together with shapes (34,34,3) (300,222,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/84.jpg (operands could not be broadcast together with shapes (34,34,3) (500,357,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/8081.jpg (operands could not be broadcast together with shapes (34,34,3) (381,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/1522.jpg (operands could not be broadcast together with shapes (34,34,3) (327,450,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/5020.jpg (operands could not be broadcast together with shapes (34,34,3) (400,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/5250.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/9632.jpg (operands could not be broadcast together with shapes (34,34,3) (500,176,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10625.jpg (operands could not be broadcast together with shapes (34,34,3) (320,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/11224.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/12495.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/9377.jpg (operands could not be broadcast together with shapes (34,34,3) (240,320,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/10348.jpg (operands could not be broadcast together with shapes (34,34,3) (425,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/8745.jpg (operands could not be broadcast together with shapes (34,34,3) (410,400,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/5426.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/1600.jpg (operands could not be broadcast together with shapes (34,34,3) (375,500,3) )
# Atlandı: /kaggle/working/cats_vs_dogs_split/test/Dog/2590.jpg (operands could not be broadcast together with shapes (34,34,3) (360,348,3) )
# Tüm test görselleri için Grad-CAM oluşturuldu ve kaydedildi.

# %% [markdown]
# ## Tüm Test Görselleri için Grad-CAM Oluşturma ve Kaydetme
#
# - Test klasöründeki "Cat" ve "Dog" kategorilerindeki tüm görseller için Grad-CAM hesaplandı.
# - `get_img_array` ile görseller array'e dönüştürüldü.
# - `make_gradcam_heatmap` ile heatmap oluşturuldu.
# - `display_gradcam` ile heatmap görselin üzerine uygulandı.
# - Sonuçlar `gradcam_results` klasörüne kaydedildi.
# - Hatalı veya bozuk görseller atlandı.

# %%
import matplotlib.pyplot as plt

# Eğitim & Doğrulama Accuracy grafiği
plt.figure(figsize=(8,6))
plt.plot(history.history['accuracy'], label='Eğitim Accuracy')
plt.plot(history.history['val_accuracy'], label='Doğrulama Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Eğitim & Doğrulama Loss grafiği
plt.figure(figsize=(8,6))
plt.plot(history.history['loss'], label='Eğitim Loss')
plt.plot(history.history['val_loss'], label='Doğrulama Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## Modelin Eğitim Performans Grafikleri
#
# - **Accuracy Grafiği:** Eğitim ve doğrulama accuracy değerlerinin epochlara göre değişimi.
# - **Loss Grafiği:** Eğitim ve doğrulama kayıp (loss) değerlerinin epochlara göre değişimi.
#
# Bu grafikler modelin öğrenme sürecini görselleştirir ve overfitting veya underfitting durumlarını gözlemlemeye yardımcı olur.

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Test verisini yeniden yükle (ImageDataGenerator ile)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    "/kaggle/working/cats_vs_dogs_split/test",
    target_size=(150,150),
    batch_size=32,
    class_mode='binary',
    shuffle=False
)

# Modeli test setinde değerlendir
loss, acc = model.evaluate(test_generator, verbose=1)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {acc:.4f}")

# Tahminler
y_pred = model.predict(test_generator)
y_pred_classes = (y_pred > 0.5).astype("int32")
y_true = test_generator.classes

# Karışıklık matrisi
cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel("Tahmin")
plt.ylabel("Gerçek")
plt.title("Karışıklık Matrisi")
plt.show()

# Sınıflandırma raporu
print("\nSınıflandırma Raporu:\n")
print(classification_report(y_true, y_pred_classes, target_names=test_generator.class_indices.keys()))
# Out:
# Found 5002 images belonging to 2 classes.
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 7s 44ms/step - accuracy: 0.7738 - loss: 0.4803
# Test Loss: 0.4072
# Test Accuracy: 0.8183
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step
# Sınıflandırma Raporu:
#
#               precision    recall  f1-score   support
#
#          Cat       0.86      0.76      0.81      2501
#          Dog       0.78      0.88      0.83      2501
#
#     accuracy                           0.82      5002
#    macro avg       0.82      0.82      0.82      5002
# weighted avg       0.82      0.82      0.82      5002

# %% [markdown]
# ## Model Değerlendirme: Test Verisi
#
# - **Test Loss ve Accuracy:** Modelin test setindeki performansını özetler.
# - **Karışıklık Matrisi (Confusion Matrix):** Modelin hangi sınıfları doğru veya yanlış tahmin ettiğini görselleştirir.
# - **Sınıflandırma Raporu (Classification Report):** Precision, recall ve F1-score değerleri ile sınıf bazlı performansı özetler.
#
# Bu adım modelin gerçek veri üzerindeki doğruluğunu ve sınıflara göre başarısını incelemeye yarar.
